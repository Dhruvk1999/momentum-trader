# %%
import pandas as pd 
import numpy as np
import talib
import yfinance as yf
from datetime import date, timedelta

symbols = list(pd.read_csv("niftyfo.csv")["SYMBOL"])
symbols = [x.strip()+".NS" for x in symbols[5:]] 
def macd_filter():
    result = pd.DataFrame()
    start_date = date.today() -timedelta(days = 50)
    end_date = date.today() + timedelta(days=1)
    for symbol in symbols:
        tdata  = yf.download(symbol,start = start_date,end = end_date)
        macd, signal, _ = talib.MACD(tdata['Close'], fastperiod=3, slowperiod=15, signalperiod=9)
        tdata["BuySignal"] = ((macd > 0.95*signal) & (macd.shift(1) <= signal.shift(1))).astype(int)
        tdata["SellSignal"] = ((macd < signal) & (macd.shift(1) >= signal.shift(1))).astype(int)
        
        # Calculating RSI for 4 days and 14 days
        tdata['RSI_4'] = talib.RSI(tdata['Close'], timeperiod=4)
        tdata['RSI_14'] = talib.RSI(tdata['Close'], timeperiod=14)
        
        # Calculating Rate of Change for 3 days
        tdata['ROC_3'] = talib.ROC(tdata['Close'], timeperiod=3)
        
        tdata["Symbol"] = symbol
        
        #appending to the result
        result = pd.concat([result,tdata[tdata.BuySignal == 1]])
        result = pd.concat([result,tdata[tdata.SellSignal == 1]])
    return result
        
        
#     data["BuySignal"] = 1 
#     data["SellSignal"] = 1
#     macd, signal, _ = talib.MACD(data['Close'], fastperiod=12, slowperiod=26, signalperiod=9)
#     data['EMA3'] = data['Close'].ewm(span=3, adjust=False).mean()
#     data['EMA15'] = data['Close'].ewm(span=15, adjust=False).mean()
#     data['BuySignal'] = ((data['EMA3'] > data['EMA15']) & (data['EMA3'].shift(1) <= data['EMA15'].shift(1))).astype(int)

# %%
a= macd_filter()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
b= a[a.index == '2024-01-04']
b[(b["BuySignal"] == 1)& (b["ROC_3"]<10) & (b["ROC_3"]>3)  & (b["RSI_4"] >60)]
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2024-01-04  4818.899902  4866.000000  4794.000000  4845.549805  4845.549805
# 2024-01-04  1480.000000  1528.599976  1460.099976  1527.000000  1527.000000
# 2024-01-04   718.000000   753.599976   717.500000   750.349976   750.349976
# 2024-01-04   173.949997   178.300003   173.800003   176.649994   176.649994
# 2024-01-04  3074.000000  3098.000000  3068.600098  3094.750000  3094.750000
# 2024-01-04   397.799988   407.899994   397.100006   407.100006   407.100006
#
#              Volume  BuySignal  SellSignal      RSI_4     RSI_14     ROC_3  \
# Date
# 2024-01-04    84831          1           0  79.341949  63.235545  3.488736
# 2024-01-04   339182          1           0  78.473465  67.398863  4.160982
# 2024-01-04  4075227          1           0  82.667100  74.006529  3.696794
# 2024-01-04  3087694          1           0  71.816838  62.504921  3.093077
# ...

# %%
b= a[a.index == '2023-12-27']
b[(b["BuySignal"] == 0)& (b["ROC_3"] < 3) & (b["RSI_4"] <60)]
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2023-12-27  1269.000000  1271.550049  1216.750000  1234.949951  1234.949951
# 2023-12-27   750.700012   757.849976   730.299988   734.950012   734.950012
# 2023-12-27   251.899994   254.399994   251.199997   251.800003   251.800003
# 2023-12-27  7096.000000  7096.000000  6985.000000  7005.000000  7005.000000
#
#              Volume  BuySignal  SellSignal      RSI_4     RSI_14     ROC_3  \
# Date
# 2023-12-27  1057075          0           1  51.455680  58.827055  2.660127
# 2023-12-27   612259          0           1  50.504885  56.056459  0.933872
# 2023-12-27  7814967          0           1  36.547603  52.540831 -1.621408
# 2023-12-27    56355          0           1  58.791311  60.879756  2.077244
#
#                    Symbol
# Date
# 2023-12-27  COROMANDEL.NS
# 2023-12-27        GNFC.NS
# 2023-12-27        VEDL.NS
# 2023-12-27        ATUL.NS
