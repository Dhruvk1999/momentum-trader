# %%
from volumeSpikeDetector import *
from utility import *
# volume spike detector
import pandas as pd
import numpy as np
from datetime import date
from nsepy import symbols
from indicators import *
import yfinance as yf
import sys
from IPython.display import display, clear_output
from IPython.utils import io
import time

# %%
data=load_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
result=filterVolumeSpike(data,1.7)
result['upOrDown']=np.where((result["Close"]-result["Open"]>0)>0,1,0)
result.loc['2023-04-12'].reset_index(drop=True).style.apply(highlight_greaterthan, threshold=1, column='upOrDown', axis=1)
# Out:
# <style type="text/css">
# #T_da338_row0_col0, #T_da338_row0_col1, #T_da338_row0_col2, #T_da338_row0_col3, #T_da338_row0_col4, #T_da338_row0_col5, #T_da338_row0_col6, #T_da338_row0_col7, #T_da338_row1_col0, #T_da338_row1_col1, #T_da338_row1_col2, #T_da338_row1_col3, #T_da338_row1_col4, #T_da338_row1_col5, #T_da338_row1_col6, #T_da338_row1_col7, #T_da338_row2_col0, #T_da338_row2_col1, #T_da338_row2_col2, #T_da338_row2_col3, #T_da338_row2_col4, #T_da338_row2_col5, #T_da338_row2_col6, #T_da338_row2_col7, #T_da338_row10_col0, #T_da338_row10_col1, #T_da338_row10_col2, #T_da338_row10_col3, #T_da338_row10_col4, #T_da338_row10_col5, #T_da338_row10_col6, #T_da338_row10_col7, #T_da338_row13_col0, #T_da338_row13_col1, #T_da338_row13_col2, #T_da338_row13_col3, #T_da338_row13_col4, #T_da338_row13_col5, #T_da338_row13_col6, #T_da338_row13_col7, #T_da338_row14_col0, #T_da338_row14_col1, #T_da338_row14_col2, #T_da338_row14_col3, #T_da338_row14_col4, #T_da338_row14_col5, #T_da338_row14_col6, #T_da338_row14_col7 {
#   background-color: #ff0047;
# }
# #T_da338_row3_col0, #T_da338_row3_col1, #T_da338_row3_col2, #T_da338_row3_col3, #T_da338_row3_col4, #T_da338_row3_col5, #T_da338_row3_col6, #T_da338_row3_col7, #T_da338_row4_col0, #T_da338_row4_col1, #T_da338_row4_col2, #T_da338_row4_col3, #T_da338_row4_col4, #T_da338_row4_col5, #T_da338_row4_col6, #T_da338_row4_col7, #T_da338_row5_col0, #T_da338_row5_col1, #T_da338_row5_col2, #T_da338_row5_col3, #T_da338_row5_col4, #T_da338_row5_col5, #T_da338_row5_col6, #T_da338_row5_col7, #T_da338_row6_col0, #T_da338_row6_col1, #T_da338_row6_col2, #T_da338_row6_col3, #T_da338_row6_col4, #T_da338_row6_col5, #T_da338_row6_col6, #T_da338_row6_col7, #T_da338_row7_col0, #T_da338_row7_col1, #T_da338_row7_col2, #T_da338_row7_col3, #T_da338_row7_col4, #T_da338_row7_col5, #T_da338_row7_col6, #T_da338_row7_col7, #T_da338_row8_col0, #T_da338_row8_col1, #T_da338_row8_col2, #T_da338_row8_col3, #T_da338_row8_col4, #T_da338_row8_col5, #T_da338_row8_col6, #T_da338_row8_col7, #T_da338_row9_col0, #T_da338_row9_col1, #T_da338_row9_col2, #T_da338_row9_col3, #T_da338_row9_col4, #T_da338_row9_col5, #T_da338_row9_col6, #T_da338_row9_col7, #T_da338_row11_col0, #T_da338_row11_col1, #T_da338_row11_col2, #T_da338_row11_col3, #T_da338_row11_col4, #T_da338_row11_col5, #T_da338_row11_col6, #T_da338_row11_col7, #T_da338_row12_col0, #T_da338_row12_col1, #T_da338_row12_col2, #T_da338_row12_col3, #T_da338_row12_col4, #T_da338_row12_col5, #T_da338_row12_col6, #T_da338_row12_col7, #T_da338_row15_col0, #T_da338_row15_col1, #T_da338_row15_col2, #T_da338_row15_col3, #T_da338_row15_col4, #T_da338_row15_col5, #T_da338_row15_col6, #T_da338_row15_col7 {
#   background-color: green;
# }
# </style>
# <table id="T_da338">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_da338_level0_col0" class="col_heading level0 col0" >Open</th>
#       <th id="T_da338_level0_col1" class="col_heading level0 col1" >High</th>
#       <th id="T_da338_level0_col2" class="col_heading level0 col2" >Low</th>
#       <th id="T_da338_level0_col3" class="col_heading level0 col3" >Close</th>
#       <th id="T_da338_level0_col4" class="col_heading level0 col4" >Adj Close</th>
#       <th id="T_da338_level0_col5" class="col_heading level0 col5" >Volume</th>
#       <th id="T_da338_level0_col6" class="col_heading level0 col6" >Symbol</th>
#       <th id="T_da338_level0_col7" class="col_heading level0 col7" >upOrDown</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_da338_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_da338_row0_col0" class="data row0 col0" >991.299988</td>
#       <td id="T_da338_row0_col1" class="data row0 col1" >991.299988</td>
#       <td id="T_da338_row0_col2" class="data row0 col2" >920.000000</td>
#       <td id="T_da338_row0_col3" class="data row0 col3" >941.849976</td>
#       <td id="T_da338_row0_col4" class="data row0 col4" >941.849976</td>
#       <td id="T_da338_row0_col5" class="data row0 col5" >8200565</td>
#       <td id="T_da338_row0_col6" class="data row0 col6" >ADANIGREEN</td>
#       <td id="T_da338_row0_col7" class="data row0 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_da338_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_da338_row1_col0" class="data row1 col0" >994.000000</td>
#       <td id="T_da338_row1_col1" class="data row1 col1" >994.000000</td>
#       <td id="T_da338_row1_col2" class="data row1 col2" >926.049988</td>
#       <td id="T_da338_row1_col3" class="data row1 col3" >938.849976</td>
#       <td id="T_da338_row1_col4" class="data row1 col4" >938.849976</td>
#       <td id="T_da338_row1_col5" class="data row1 col5" >2780202</td>
#       <td id="T_da338_row1_col6" class="data row1 col6" >ATGL</td>
#       <td id="T_da338_row1_col7" class="data row1 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_da338_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_da338_row2_col0" class="data row2 col0" >1097.000000</td>
#       <td id="T_da338_row2_col1" class="data row2 col1" >1099.000000</td>
#       <td id="T_da338_row2_col2" class="data row2 col2" >1015.000000</td>
#       <td id="T_da338_row2_col3" class="data row2 col3" >1043.449951</td>
#       <td id="T_da338_row2_col4" class="data row2 col4" >1043.449951</td>
#       <td id="T_da338_row2_col5" class="data row2 col5" >2431503</td>
#       <td id="T_da338_row2_col6" class="data row2 col6" >ADANITRANS</td>
#       <td id="T_da338_row2_col7" class="data row2 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_da338_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_da338_row3_col0" class="data row3 col0" >2755.550049</td>
#       <td id="T_da338_row3_col1" class="data row3 col1" >2806.199951</td>
#       <td id="T_da338_row3_col2" class="data row3 col2" >2751.000000</td>
#       <td id="T_da338_row3_col3" class="data row3 col3" >2786.750000</td>
#       <td id="T_da338_row3_col4" class="data row3 col4" >2786.750000</td>
#       <td id="T_da338_row3_col5" class="data row3 col5" >2235264</td>
#       <td id="T_da338_row3_col6" class="data row3 col6" >ASIANPAINT</td>
#       <td id="T_da338_row3_col7" class="data row3 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_da338_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_da338_row4_col0" class="data row4 col0" >4177.399902</td>
#       <td id="T_da338_row4_col1" class="data row4 col1" >4307.350098</td>
#       <td id="T_da338_row4_col2" class="data row4 col2" >4170.500000</td>
#       <td id="T_da338_row4_col3" class="data row4 col3" >4286.000000</td>
#       <td id="T_da338_row4_col4" class="data row4 col4" >4286.000000</td>
#       <td id="T_da338_row4_col5" class="data row4 col5" >991923</td>
#       <td id="T_da338_row4_col6" class="data row4 col6" >BAJAJ-AUTO</td>
#       <td id="T_da338_row4_col7" class="data row4 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_da338_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_da338_row5_col0" class="data row5 col0" >6030.149902</td>
#       <td id="T_da338_row5_col1" class="data row5 col1" >6059.000000</td>
#       <td id="T_da338_row5_col2" class="data row5 col2" >5994.149902</td>
#       <td id="T_da338_row5_col3" class="data row5 col3" >6039.350098</td>
#       <td id="T_da338_row5_col4" class="data row5 col4" >6039.350098</td>
#       <td id="T_da338_row5_col5" class="data row5 col5" >51074</td>
#       <td id="T_da338_row5_col6" class="data row5 col6" >BAJAJHLDNG</td>
#       <td id="T_da338_row5_col7" class="data row5 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_da338_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_da338_row6_col0" class="data row6 col0" >217.350006</td>
#       <td id="T_da338_row6_col1" class="data row6 col1" >227.000000</td>
#       <td id="T_da338_row6_col2" class="data row6 col2" >216.250000</td>
#       <td id="T_da338_row6_col3" class="data row6 col3" >223.649994</td>
#       <td id="T_da338_row6_col4" class="data row6 col4" >223.649994</td>
#       <td id="T_da338_row6_col5" class="data row6 col5" >12680041</td>
#       <td id="T_da

# %%
watchList=list(result.loc['2023-03-24'].Symbol.unique())
for i in range(0,len(watchList)):
    watchList[i]=watchList[i]+".NS"
watchList
# Out:
# ['ACC.NS',
#  'ADANIENT.NS',
#  'ADANIGREEN.NS',
#  'ATGL.NS',
#  'ADANITRANS.NS',
#  'BEL.NS',
#  'CIPLA.NS',
#  'NYKAA.NS',
#  'GLAND.NS',
#  'HAL.NS',
#  'KOTAKBANK.NS',
#  'LICI.NS',
#  'TATAPOWER.NS',
#  'VEDL.NS',
#  'ZOMATO.NS']

# %%
from indicators import rsi

data=rsi(data)

# %%
from nsepy import symbols
from utility import * 

symbols=pd.DataFrame(symbols.get_index_constituents_list("nifty100"))
df_grouped=data.groupby("Symbol")
result=[]

for i in symbols.Symbol:
    try:
        temp=df_grouped.get_group(i)
        int_value=getIntrinsicValue(i)
        #temp=rsi(temp,4)
        #temp=sma(temp,200)
        #current_average=list(temp.sma200)[-1]
        current_price=list(temp.Close)[-1]
        current_rsi=list(temp.rsi)[-1];
        if current_rsi<30 and int_value<current_price:
            
            print(i,int_value,current_price)
    except:
        pass
        print(f"cannot fetch {i}")
# Out:
# cannot fetch ATGL
# AXISBANK 753.56 839.9000244140625
# cannot fetch BAJAJ-AUTO
# BAJAJFINSV 618.7 1240.6500244140625
# BANDHANBNK 136.49 203.10000610351562
# cannot fetch BERGEPAINT
# BEL 36.12 91.55000305175781
# BIOCON 100.46 198.6999969482422
# cannot fetch BOSCHLTD
# BRITANNIA 1122.52 4199.9501953125
# CHOLAFIN 554.21 727.6500244140625
# CIPLA 797.98 877.25
# DLF 135.64 354.25
# NYKAA 2.93 137.64999389648438
# HDFCLIFE 107.72 492.25
# ICICIBANK 569.75 852.4000244140625
# ICICIPRULI 82.63 420.25
# ITC 224.4 378.70001220703125
# cannot fetch INDUSTOWER
# INFY 825.88 1380.6500244140625
# JSWSTEEL 355.02 657.7999877929688
# cannot fetch LTIM
# LICI 416.16 560.0
# cannot fetch M&M
# MARICO 175.78 477.20001220703125
# MPHASIS 1617.92 1737.4000244140625
# PAYTM -862.35 619.4500122070312
# cannot fetch RELIANCE
# SBICARD 394.14 723.5499877929688
# cannot fetch SRF
# cannot fetch MOTHERSON
# SIEMENS 896.99 3333.449951171875
# cannot fetch TATACONSUM
# TATAMOTORS -285.16 416.5
# cannot fetch UPL
# cannot fetch MCDOWELL-N
# ZOMATO -2.4 50.650001525878906

# %%
# fetch latest price of the symbols above

watchLivePrice=pd.DataFrame()
for symbol in watchList:
    with io.capture_output() as captured:
        watchLivePrice=pd.concat([watchLivePrice,yf.download(tickers=symbol, period='1d', interval='1m').tail(1)]);
    watchLivePrice["Symbol"]=symbol
    watchLivePrice['upOrDown']=np.where((watchLivePrice["Close"]-watchLivePrice["Open"]>0)>0,1,0)
    watchLivePrice.reset_index(drop=True).style.apply(highlight_greaterthan, threshold=1, column='upOrDown', axis=1)

# %%
watchLivePrice.reset_index(drop=True).style.apply(highlight_greaterthan, threshold=1, column='upOrDown', axis=1)
# Out:
# <style type="text/css">
# #T_f3042_row0_col0, #T_f3042_row0_col1, #T_f3042_row0_col2, #T_f3042_row0_col3, #T_f3042_row0_col4, #T_f3042_row0_col5, #T_f3042_row0_col6, #T_f3042_row0_col7, #T_f3042_row6_col0, #T_f3042_row6_col1, #T_f3042_row6_col2, #T_f3042_row6_col3, #T_f3042_row6_col4, #T_f3042_row6_col5, #T_f3042_row6_col6, #T_f3042_row6_col7, #T_f3042_row9_col0, #T_f3042_row9_col1, #T_f3042_row9_col2, #T_f3042_row9_col3, #T_f3042_row9_col4, #T_f3042_row9_col5, #T_f3042_row9_col6, #T_f3042_row9_col7, #T_f3042_row11_col0, #T_f3042_row11_col1, #T_f3042_row11_col2, #T_f3042_row11_col3, #T_f3042_row11_col4, #T_f3042_row11_col5, #T_f3042_row11_col6, #T_f3042_row11_col7, #T_f3042_row12_col0, #T_f3042_row12_col1, #T_f3042_row12_col2, #T_f3042_row12_col3, #T_f3042_row12_col4, #T_f3042_row12_col5, #T_f3042_row12_col6, #T_f3042_row12_col7, #T_f3042_row13_col0, #T_f3042_row13_col1, #T_f3042_row13_col2, #T_f3042_row13_col3, #T_f3042_row13_col4, #T_f3042_row13_col5, #T_f3042_row13_col6, #T_f3042_row13_col7 {
#   background-color: green;
# }
# #T_f3042_row1_col0, #T_f3042_row1_col1, #T_f3042_row1_col2, #T_f3042_row1_col3, #T_f3042_row1_col4, #T_f3042_row1_col5, #T_f3042_row1_col6, #T_f3042_row1_col7, #T_f3042_row2_col0, #T_f3042_row2_col1, #T_f3042_row2_col2, #T_f3042_row2_col3, #T_f3042_row2_col4, #T_f3042_row2_col5, #T_f3042_row2_col6, #T_f3042_row2_col7, #T_f3042_row3_col0, #T_f3042_row3_col1, #T_f3042_row3_col2, #T_f3042_row3_col3, #T_f3042_row3_col4, #T_f3042_row3_col5, #T_f3042_row3_col6, #T_f3042_row3_col7, #T_f3042_row4_col0, #T_f3042_row4_col1, #T_f3042_row4_col2, #T_f3042_row4_col3, #T_f3042_row4_col4, #T_f3042_row4_col5, #T_f3042_row4_col6, #T_f3042_row4_col7, #T_f3042_row5_col0, #T_f3042_row5_col1, #T_f3042_row5_col2, #T_f3042_row5_col3, #T_f3042_row5_col4, #T_f3042_row5_col5, #T_f3042_row5_col6, #T_f3042_row5_col7, #T_f3042_row7_col0, #T_f3042_row7_col1, #T_f3042_row7_col2, #T_f3042_row7_col3, #T_f3042_row7_col4, #T_f3042_row7_col5, #T_f3042_row7_col6, #T_f3042_row7_col7, #T_f3042_row8_col0, #T_f3042_row8_col1, #T_f3042_row8_col2, #T_f3042_row8_col3, #T_f3042_row8_col4, #T_f3042_row8_col5, #T_f3042_row8_col6, #T_f3042_row8_col7, #T_f3042_row10_col0, #T_f3042_row10_col1, #T_f3042_row10_col2, #T_f3042_row10_col3, #T_f3042_row10_col4, #T_f3042_row10_col5, #T_f3042_row10_col6, #T_f3042_row10_col7, #T_f3042_row14_col0, #T_f3042_row14_col1, #T_f3042_row14_col2, #T_f3042_row14_col3, #T_f3042_row14_col4, #T_f3042_row14_col5, #T_f3042_row14_col6, #T_f3042_row14_col7 {
#   background-color: #ff0047;
# }
# </style>
# <table id="T_f3042">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f3042_level0_col0" class="col_heading level0 col0" >Open</th>
#       <th id="T_f3042_level0_col1" class="col_heading level0 col1" >High</th>
#       <th id="T_f3042_level0_col2" class="col_heading level0 col2" >Low</th>
#       <th id="T_f3042_level0_col3" class="col_heading level0 col3" >Close</th>
#       <th id="T_f3042_level0_col4" class="col_heading level0 col4" >Adj Close</th>
#       <th id="T_f3042_level0_col5" class="col_heading level0 col5" >Volume</th>
#       <th id="T_f3042_level0_col6" class="col_heading level0 col6" >Symbol</th>
#       <th id="T_f3042_level0_col7" class="col_heading level0 col7" >upOrDown</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3042_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f3042_row0_col0" class="data row0 col0" >1697.250000</td>
#       <td id="T_f3042_row0_col1" class="data row0 col1" >1698.000000</td>
#       <td id="T_f3042_row0_col2" class="data row0 col2" >1695.949951</td>
#       <td id="T_f3042_row0_col3" class="data row0 col3" >1697.849976</td>
#       <td id="T_f3042_row0_col4" class="data row0 col4" >1697.849976</td>
#       <td id="T_f3042_row0_col5" class="data row0 col5" >1266</td>
#       <td id="T_f3042_row0_col6" class="data row0 col6" >ZOMATO.NS</td>
#       <td id="T_f3042_row0_col7" class="data row0 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f3042_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f3042_row1_col0" class="data row1 col0" >1740.650024</td>
#       <td id="T_f3042_row1_col1" class="data row1 col1" >1740.650024</td>
#       <td id="T_f3042_row1_col2" class="data row1 col2" >1740.650024</td>
#       <td id="T_f3042_row1_col3" class="data row1 col3" >1740.650024</td>
#       <td id="T_f3042_row1_col4" class="data row1 col4" >1740.650024</td>
#       <td id="T_f3042_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_f3042_row1_col6" class="data row1 col6" >ZOMATO.NS</td>
#       <td id="T_f3042_row1_col7" class="data row1 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f3042_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f3042_row2_col0" class="data row2 col0" >1031.449951</td>
#       <td id="T_f3042_row2_col1" class="data row2 col1" >1031.449951</td>
#       <td id="T_f3042_row2_col2" class="data row2 col2" >1031.449951</td>
#       <td id="T_f3042_row2_col3" class="data row2 col3" >1031.449951</td>
#       <td id="T_f3042_row2_col4" class="data row2 col4" >1031.449951</td>
#       <td id="T_f3042_row2_col5" class="data row2 col5" >2755</td>
#       <td id="T_f3042_row2_col6" class="data row2 col6" >ZOMATO.NS</td>
#       <td id="T_f3042_row2_col7" class="data row2 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f3042_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f3042_row3_col0" class="data row3 col0" >1007.750000</td>
#       <td id="T_f3042_row3_col1" class="data row3 col1" >1008.549988</td>
#       <td id="T_f3042_row3_col2" class="data row3 col2" >1003.299988</td>
#       <td id="T_f3042_row3_col3" class="data row3 col3" >1006.000000</td>
#       <td id="T_f3042_row3_col4" class="data row3 col4" >1006.000000</td>
#       <td id="T_f3042_row3_col5" class="data row3 col5" >35517</td>
#       <td id="T_f3042_row3_col6" class="data row3 col6" >ZOMATO.NS</td>
#       <td id="T_f3042_row3_col7" class="data row3 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f3042_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f3042_row4_col0" class="data row4 col0" >1130.000000</td>
#       <td id="T_f3042_row4_col1" class="data row4 col1" >1131.699951</td>
#       <td id="T_f3042_row4_col2" class="data row4 col2" >1129.000000</td>
#       <td id="T_f3042_row4_col3" class="data row4 col3" >1129.349976</td>
#       <td id="T_f3042_row4_col4" class="data row4 col4" >1129.349976</td>
#       <td id="T_f3042_row4_col5" class="data row4 col5" >20842</td>
#       <td id="T_f3042_row4_col6" class="data row4 col6" >ZOMATO.NS</td>
#       <td id="T_f3042_row4_col7" class="data row4 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f3042_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f3042_row5_col0" class="data row5 col0" >91.650002</td>
#       <td id="T_f3042_row5_col1" class="data row5 col1" >91.699997</td>
#       <td id="T_f3042_row5_col2" class="data row5 col2" >91.599998</td>
#       <td id="T_f3042_row5_col3" class="data row5 col3" >91.599998</td>
#       <td id="T_f3042_row5_col4" class="data row5 col4" >91.599998</td>
#       <td id="T_f3042_row5_col5" class="data row5 col5" >42809</td>
#       <td id="T_f3042_row5_col6" class="data row5 col6" >ZOMATO.NS</td>
#       <td id="T_f3042_row5_col7" class="data row5 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f3042_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f3042_row6_col0" class="data row6 col0" >878.000000</td>
#       <td id="T_f3042_row6_col1" class="data row6 col1" >878.900024</td>
#       <td id="T_f3042_row6_col2" class="data row6 col2" >876.250000</td>
#       <td id="T_f3042_row6_col3" class="data row6 col3" >878.900024</td>
#       <td id="T_f3042_row6_col4" class="data row6 col4" >878.900024</td>
#       <td id="T_f3042_row6_col5" class="data row6 col5" >3229</td>
#       <td id="T_f3042_row6_col6" class="data row6 col6" >ZOMATO.NS</td>
#       <td id="T_f3042_row6_col7" class="data row6 col7" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f3042_level0_row7" class="row_head

# %%
while(True):
    with io.capture_output() as captured:
        price=yf.download(tickers='INDUSINDBK.NS', period='1d', interval='1m',rounding=True).tail(1)
    clear_output(wait=True)
    display(price)
    time.sleep(0.3)
    if((price.Close<1066.4)[0]):
        AlertRing()
        break
# Out:
#                               Open     High      Low    Close  Adj Close  \
# Datetime
# 2023-03-31 10:13:00+05:30  1065.35  1065.35  1065.35  1065.35    1065.35
#
#                            Volume
# Datetime
# 2023-03-31 10:13:00+05:30       0

# %%
def watchPrice(symbol,trigger,long=True):
    while(True):
    with io.capture_output() as captured:
        price=yf.download(tickers=symbol+'.NS', period='1d', interval='1m',rounding=True).tail(1)
    clear_output(wait=True)
    display(price)
    time.sleep(0.3)
    if((price.Close>369.9)[0] & long==True):
        AlertRing()
        break
    else if ((price.Close<trigger)[0] & long==False):
        AlertRing()
        break

# %%
from random import uniform
import time
from IPython.display import display, clear_output

def black_box():
    i = 1
    while True:
        clear_output(wait=True)
        display('Iteration '+str(i)+' Score: '+str(uniform(0, 1)))
        time.sleep(1)
        i += 1

# %%
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open   High         Low       Close   Adj Close   Volume
# Date
# 2023-03-22  376.950012  378.0  374.200012  376.149994  376.149994  3360615

# %%
price=yf.download(tickers='NIFTY_FIN_SERVICE.NS',start="2023-02-25", end=date.today()).tail(1)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
price
# Out:
#                     Open          High       Low     Close  Adj Close  Volume
# Date
# 2023-04-03  18096.650391  18185.150391  18041.75  18164.75   18164.75       0

# %% [markdown]
# ## TextBlob for sentiment analysis
#
# The TextBlob library in Python returns sentiment polarity and subjectivity values as part of its sentiment analysis.
#
# * Polarity: Polarity represents the sentiment polarity of a text, ranging from -1 to 1. A polarity score of -1 indicates highly negative sentiment, 0 indicates neutral sentiment, and 1 indicates highly positive sentiment. Polarity values closer to -1 or 1 indicate stronger sentiment, while values closer to 0 indicate weaker or neutral sentiment.
#
# * Subjectivity: Subjectivity represents the subjectivity of a text, ranging from 0 to 1. A subjectivity score of 0 indicates objective text, meaning it is factual or unbiased, while a score of 1 indicates highly subjective text, meaning it is opinionated or biased. Subjectivity values between 0 and 1 indicate varying degrees of subjectivity.

# %%
from newsapi import NewsApiClient
from textblob import TextBlob

# Set up your News API key
newsapi = NewsApiClient(api_key='4a51169c54fb4d2880c2f0445f1a2adc')

# Define the stock symbol for which you want to extract news
stock_symbol = 'GLENMARK'

# Define the number of news articles to retrieve
num_articles = 5

# Get news articles related to the stock symbol
articles = newsapi.get_everything(q=stock_symbol, language='en', sort_by='relevancy', page_size=num_articles)

# Extract sentiment from each news article
for article in articles['articles']:
    title = article['title']
    description = article['description']
    content = article['content']
    
    # Concatenate the title, description, and content of the article
    text = f"{title}. {description}. {content}"
    
    # Perform sentiment analysis using TextBlob
    analysis = TextBlob(text)
    polarity = analysis.sentiment.polarity
    subjectivity = analysis.sentiment.subjectivity
    
    # Print the sentiment analysis results
    print("Title: ", title)
    print("Sentiment Polarity: ", polarity)
    print("Sentiment Subjectivity: ", subjectivity)
    print("----")
# Out:
# Title:  What should you do with Bandhan Bank, Kalyan and Glenmark Pharma?
# Sentiment Polarity:  -0.016527777777777773
# Sentiment Subjectivity:  0.2901388888888889
# ----
# Title:  Topical Drug Delivery Global Market Report 2023
# Sentiment Polarity:  -0.001785714285714285
# Sentiment Subjectivity:  0.21857142857142856
# ----
# Title:  Glenmark exploring stake sale in life sciences arm to reduce debt
# Sentiment Polarity:  0.020833333333333332
# Sentiment Subjectivity:  0.6666666666666666
# ----
# Title:  Glenmark gets USFDA nod to market generic medication
# Sentiment Polarity:  0.0
# Sentiment Subjectivity:  0.0
# ----
# Title:  Glenmark gets USFDA nod for generic drug with 180-day exclusivity
# Sentiment Polarity:  0.0
# Sentiment Subjectivity:  0.4
# ----

# %%
indices=["^NSEI","^NSEBANK","^CNXIT","^CNXAUTO","^CNXPHARMA","^CNXMETAL","^CNXREALTY","^CNXMEDIA","^CNXINFRA","NIFTY_OIL_AND_GAS.NS","NIFTY_HEALTHCARE.NS"]
