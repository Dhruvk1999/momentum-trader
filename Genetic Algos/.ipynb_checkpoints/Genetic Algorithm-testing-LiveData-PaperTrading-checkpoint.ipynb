# %%
from evolution_operators import *
from utility_functions import *

# %%
def evaluate_strategy(data, fast_period, slow_period, fast_p_exit, slow_p_exit, stop_loss_percentage):
    # Calculate indicators
#     print(fast_period,slow_period,fast_p_exit, slow_p_exit, stop_loss_percentage)
    data['MACD'], data['Signal'] = calculate_macd(data, fast_period, slow_period)
    data['MACD_E'], data['Signal_E'] = calculate_macd(data, fast_p_exit, slow_p_exit)

    data['ROC'] = calculate_roc(data, 3)
#     data['RSI_Derivative'] = calculate_rsi_derivative(data, rsi_period)
    
    # Apply trailing stop-loss exit condition
#     stop_loss = trailing_stop_loss(data, stop_loss_percentage)
    
    # Simulated trading logic
    position = 0  # 0 for no position, 1 for long position
    profit = 0
    total_trades = 0
    winning_trades = 0
    stricly_winning_trades =0
    allocated_funds = 100000
    no_of_shares =0
    stop_loss_price = 0
    
    for i in range(1, len(data)):
        try:

            if position == 0:
                if data['MACD'][i] > data['Signal'][i] :#and data['ROC'][i] > 1: #and data['RSI_Derivative'][i] > rsi_derivative_threshold:
                
                    position = 1  # Buy (enter long position)
                    entry_price = data['Close'][i]
                    stop_loss_price = entry_price - (entry_price * 0.01 * stop_loss_percentage)
#                     print(f"Entry: {entry_price} on {data.index[i]} Stop Loss: {stop_loss_price}")
                    total_trades += 1
                    no_of_shares = allocated_funds//entry_price
                    
            elif position == 1 and data['MACD'][i] < data['Signal'][i]:
                
                if data['Close'][i] > entry_price:  # Adjust stop loss only when the price goes up
                    stop_loss_price = max(stop_loss_price, data['Close'][i] - (data['Close'][i] * 0.01 * stop_loss_percentage))

                if data['Low'][i] < stop_loss_price:
                    position = 0  # Sell due to stop loss
                    exit_price = data['Open'][i] if stop_loss_price > data['Open'][i] else stop_loss_price
                    trade_profit = (exit_price - entry_price) * no_of_shares  # Calculate profit/loss
                    profit=trade_profit
                    allocated_funds += profit
                    no_of_shares =0
#                     print(f"Exit: {exit_price} on {data.index[i]} exited on stop loss Allocated Funds {allocated_funds}")
#                     print(f"Profit: {profit}")
                    if(exit_price>= entry_price):
                        winning_trades += 1
                    if(exit_price> entry_price):
                        stricly_winning_trades += 1
                elif data['MACD_E'][i] < data['Signal_E'][i]:
                    position = 0  # Sell due to exit condition
                    exit_price = data['Close'][i]
                    trade_profit = (exit_price - entry_price) * no_of_shares  # Calculate profit/loss
                    profit=trade_profit#                     
#                     print(f"Exit: {exit_price} on {data.index[i]} exited on stop loss Allocated Funds {allocated_funds}")
#                     print(f"Profit: {profit}")
                    allocated_funds += profit

                    no_of_shares =0
                    if(exit_price>= entry_price):
                        winning_trades += 1
                    if(exit_price> entry_price):
                        stricly_winning_trades += 1
            
        except Exception as ex:
            print("Something caused the error",ex)
            break
        win_rate = winning_trades/total_trades if total_trades != 0 else 0
    
    return [profit,total_trades,winning_trades,stricly_winning_trades,win_rate,allocated_funds]

# %%
def trade_symbols(tickers):
    metrics = {}
    total_symbols = len(tickers)
    fund_per_symbol = 100000 / total_symbols  # Initial fund equally distributed among symbols

    for symbol in tickers:
        # Fetch historical stock data
        ticker_symbol = symbol  # Replace with your desired stock symbol
        start_date = '2022-01-01'
        end_date = '2022-12-31'
        stock_data = fetch_stock_data(ticker_symbol, start_date, end_date)

        # Genetic Algorithm parameters
        population_size = 200
        num_generations = 20
        mutation_rate = 0.1
        elite_size = 30
        consecutive_threshold = 3  # Number of consecutive generations with no fitness improvement to consider saturation
        fitness_history = []  # To store fitness scores across generations

        # GA: Initialization
        def generate_individual():
            fast_p = random.randint(2,10)
            slow_p = random.randint(fast_p,20)
            fast_p_exit = random.randint(2,10)
            slow_p_exit = random.randint(fast_p_exit,20)
            return [fast_p,slow_p,fast_p_exit,slow_p_exit, random.uniform(-1,2)]


        # Known or useful parameter values
        known_parameters = [
        #     [3, 4, 1, 10,0],
        #     [7, 9, 5,9,  0],
        #     [7, 9, 5,9,  3],
        #     [2, 3, 2,4,  0],
        #     [2, 15, 6, 10, 0],
            [2, 15, 3, 3, 3],
            [2, 18, 8, 14, -0.9930604812498026]# Example set of known parameters
                             # Add more known parameter sets if available
        ]

        # Randomly generate the rest of the population
        remaining_population = [generate_individual() for _ in range(population_size - len(known_parameters))]

        # Initialize population using known parameter values and randomly generated values
        population = known_parameters + remaining_population
        # population = [generate_individual() for _ in range(population_size)]



        for generation in range(num_generations):
            fitness_scores = [evaluate_strategy(stock_data.copy(), *individual)[0] for individual in population]
            sorted_population = [x for _, x in sorted(zip(fitness_scores, population), key=lambda pair: pair[0], reverse=True)]

            new_population = []

            # Select the top K individuals (elite) for the next generation
            elite = sorted_population[:elite_size]

            # Check for convergence or other stopping criteria
            fitness_history.append(max(fitness_scores))

            # Check for convergence or other stopping criteria
            if len(fitness_history) >= consecutive_threshold:
                recent_improvements = fitness_history[-consecutive_threshold:]
                if len(set(recent_improvements)) == 1:
                    print("Saturation condition met, breaking the loop")
                    break

            # Create new population by generating offspring from the elite individuals
            new_population = generate_offspring(elite,population_size,mutation_rate)

            population = new_population



        # Find the best individual (parameters) from the final population
        best_individual_index = np.argmax(fitness_scores)
        best_individual = population[best_individual_index]
        best_fitness_score = fitness_scores[best_individual_index]

        metrics[symbol] = {
            "Best Parameters": best_individual,
            "Best Fitness Score": best_fitness_score,
            # Add other metrics you want to store for each symbol
        }

    return metrics

# %%
cd momentum-trader/
# Out:
# /home/dhruv/momentum-trader

# %%
import pandas as pd
tickers = pd.read_csv("niftyfo.csv")
tickers = [ticker.strip() for ticker in list(tickers.SYMBOL)]
tickers = [ticker+'.NS' for ticker in tickers[5:]]
tickers
# Out:
# ['BALRAMCHIN.NS',
#  'ACC.NS',
#  'ABB.NS',
#  'ALKEM.NS',
#  'ABBOTINDIA.NS',
#  'ABCAPITAL.NS',
#  'ABFRL.NS',
#  'ADANIENT.NS',
#  'ADANIPORTS.NS',
#  'APOLLOHOSP.NS',
#  'APOLLOTYRE.NS',
#  'ASTRAL.NS',
#  'AUBANK.NS',
#  'AXISBANK.NS',
#  'BAJAJ-AUTO.NS',
#  'BAJAJFINSV.NS',
#  'BAJFINANCE.NS',
#  'BALKRISIND.NS',
#  'BANDHANBNK.NS',
#  'BANKBARODA.NS',
#  'BEL.NS',
#  'BHARATFORG.NS',
#  'BHARTIARTL.NS',
#  'BHEL.NS',
#  'BOSCHLTD.NS',
#  'BPCL.NS',
#  'BRITANNIA.NS',
#  'GAIL.NS',
#  'GLENMARK.NS',
#  'BSOFT.NS',
#  'CANBK.NS',
#  'CANFINHOME.NS',
#  'CHAMBLFERT.NS',
#  'CHOLAFIN.NS',
#  'CIPLA.NS',
#  'COALINDIA.NS',
#  'CONCOR.NS',
#  'COROMANDEL.NS',
#  'CROMPTON.NS',
#  'CUB.NS',
#  'DALBHARAT.NS',
#  'DELTACORP.NS',
#  'DIXON.NS',
#  'EXIDEIND.NS',
#  'IGL.NS',
#  'GMRINFRA.NS',
#  'GNFC.NS',
#  'GRANULES.NS',
#  'GRASIM.NS',
#  'GUJGASLTD.NS',
#  'HCLTECH.NS',
#  'HDFCAMC.NS',
#  'HDFCLIFE.NS',
#  'INDUSTOWER.NS',
#  'HINDALCO.NS',
#  'AMBUJACEM.NS',
#  'BATAINDIA.NS',
#  'ASHOKLEY.NS',
#  'HINDCOPPER.NS',
#  'HINDPETRO.NS',
#  'ICICIBANK.NS',
#  'ICICIGI.NS',
#  'ICICIPRULI.NS',
#  'IDEA.NS',
#  'IDFC.NS',
#  'IEX.NS',
#  'AUROPHARMA.NS',
#  'INDHOTEL.NS',
#  'METROPOLIS.NS',
#  'BIOCON.NS',
#  'MUTHOOTFIN.NS',
#  'INDIACEM.NS',
#  'COLPAL.NS',
#  'PERSISTENT.NS',
#  'INDIAMART.NS',
#  'INDUSINDBK.NS',
#  'IRCTC.NS',
#  'JINDALSTEL.NS',
#  'JKCEMENT.NS',
#  'JSWSTEEL.NS',
#  'JUBLFOOD.NS',
#  'DIVISLAB.NS',
#  'KOTAKBANK.NS',
#  'L&TFH.NS',
#  'LALPATHLAB.NS',
#  'LAURUSLABS.NS',
#  'SHRIRAMFIN.NS',
#  'LICHSGFIN.NS',
#  'LTIM.NS',
#  'DLF.NS',
#  'LTTS.NS',
#  'LUPIN.NS',
#  'DRREDDY.NS',
#  'MANAPPURAM.NS',
#  'FEDERALBNK.NS',
#  'TRENT.NS',
#  'MARUTI.NS',
#  'MCX.NS',
#  'MFSL.NS',
#  'MGL.NS',
#  'MOTHERSON.NS',
#  'MPHASIS.NS',
#  'MRF.NS',
#  'NATIONALUM.NS',
#  'NESTLEIND.NS',
#  'NMDC.NS',
#  'NTPC.NS',
#  'HAL.NS',
#  'OBEROIRLTY.NS',
#  'HEROMOTOCO.NS',
#  'OFSS.NS',
#  'ONGC.NS',
#  'PEL.NS',
#  'PETRONET.NS',
#  'PIDILITIND.NS',
#  'PIIND.NS',
#  'IDFCFIRSTB.NS',
#  'PNB.NS',
#  'POLYCAB.NS',
#  'PVRINOX.NS',
#  'RAMCOCEM.NS',
#  'RBLBANK.NS',
#  'RECLTD.NS',
#  'RELIANCE.NS',
#  'IPCALAB.NS',
#  'SAIL.NS',
#  'ITC.NS',
#  'SBICARD.NS',
#  'SBILIFE.NS',
#  'SBIN.NS',
#  'SHREECEM.NS',
#  'SRF.NS',
#  'SUNTV.NS',
#  'SYNGENE.NS',
#  'TATACHEM.NS',
#  'TATACOMM.NS',
#  'TATACONSUM.NS',
#  'TATAMOTORS.NS',
#  'TATAPOWER.NS',
#  'TATASTEEL.NS',
#  'TCS.NS',
#  'TECHM.NS',
#  'TITAN.NS',
#  'TORNTPHARM.NS',
#  'TVSMOTOR.NS',
#  'UBL.NS',
#  'ULTRACEMCO.NS',
#  'UPL.NS',
#  'VEDL.NS',
#  'WIPRO.NS',
#  'ZYDUSLIFE.NS',
#  'NAUKRI.NS',
#  'NAVINFLUOR.NS',
#  'M&MFIN.NS',
#  'MARICO.NS',
#  'PFC.NS',
#  'AARTIIND.NS',
#  'ASIANPAINT.NS',
#  'ATUL.NS',
#  'SUNPHARMA.NS',
#  'CUMMINSIND.NS',
#  'DABUR.NS',
#  'DEEPAKNTR.NS',
#  'EICHERMOT.NS',
#  'ZEEL.NS',
#  'ESCORTS.NS',
#  'GODREJCP.NS',
#  'GODREJPROP.NS',
#  'HAVELLS.NS',
#  'HDFCBANK.NS',
#  'INDIGO.NS',
#  'INFY.NS',
#  'IOC.NS',
#  'BERGEPAINT.NS',
#  'LT.NS',
#  'MCDOWELL-N.NS',
#  'IBULHSGFIN.NS',
#  'M&M.NS',
#  'PAGEIND.NS',
#  'SIEMENS.NS',
#  'COFORGE.NS',
#  'HINDUNILVR.NS',
#  'POWERGRID.NS',
#  'VOLTAS.NS']

# %%
all_metrics = trade_symbols(tickers)

# Print metrics for all symbols
for symbol, metrics in all_metrics.items():
    print(f"Metrics for symbol {symbol}:")
    print(metrics)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# [*********************100%%**********************]  1 of 1 completed
# Saturation condition met, breaking the loop
# Metrics for symbol BALRAMCHIN.NS:
# {'Best Parameters': [3, 4, 9, 7, -0.9949905250364388], 'Best Fitness Score': 9046.65940620265}
# Metrics for symbol ACC.NS:
# {'Best Parameters': [10, 17, 6, 6, 1.1538745910349486], 'Best Fitness Score': 17164.30248735714}
# Metrics for symbol ABB.NS:
# {'Best Parameters': [3, 11, 3, 11, -0.9511373439957621], 'Best Fitness Score': 796.79296875}
# Metrics for symbol ALKEM.NS:
# {'Best Parameters': [2, 3, 4, 5, -0.9421804956799233], 'Best Fitness Score': 907.1953125}
# Metrics for symbol ABBOTINDIA.NS:
# {'Best Parameters': [2, 4, 3, 7, -0.999903365494242], 'Best Fitness Score': 6618.90234375}
# Metrics for symbol ABCAPITAL.NS:
# {'Best Parameters': [2, 7, 2, 20, -0.9930604812498026], 'Best Fitness Score': 36629.45365905762}
# Metrics for symbol ABFRL.NS:
# {'Best Parameters': [4, 15, 3, 14, -0.9930604812498026], 'Best Fitness Score': 2932.1879750286507}
# Metrics for symbol ADANIENT.NS:
# {'Best Parameters': [2, 3, 10, 16, -0.9930604812498026], 'Best Fitness Score': 2225.860685249645}
# Metrics for symbol ADANIPORTS.NS:
# {'Best Parameters': [2, 12, 3, 3, 3], 'Best Fitness Score': 12508.664320678712}
# Metrics for symbol APOLLOHOSP.NS:
# {'Best Parameters': [8, 18, 3, 7, -0.761640384607921], 'Best Fitness Score': 3955.1373457353748}
# Metrics for symbol APOLLOTYRE.NS:
# {'Best Parameters': [5, 6, 6, 20, -0.9249791343367331], 'Best Fitness Score': 21289.006839009417}
# Metrics for symbol ASTRAL.NS:
# {'Best Parameters': [2, 9, 3, 12, -0.9326211336881106], 'Best Fitness Score': 15978.26427835599}
# Metrics for symbol AUBANK.NS:
# {'Best Parameters': [6, 18, 8, 14, -0.9930604812498026], 'Best Fitness Score': 7160.009765625}
# Metrics for symbol AXISBANK.NS:
# {'Best Parameters': [3, 6, 8, 17, 1.8075701431580575], 'Best Fitness Score': 18020.845336914062}
# Metrics for symbol BAJAJ-AUTO.NS:
# {'Best Parameters': [5, 20, 3, 17, -0.9472952781946098], 'Best Fitness Score': 579.1953125}
# Metrics for symbol BAJAJFINSV.NS:
# {'Best Parameters': [4, 4, 6, 12, 0.09067181754440501], 'Best Fitness Score': 0}
# Metrics for symbol BAJFINANCE.NS:
# {'Best Parameters': [2, 4, 8, 10, -0.9930604812498026], 'Best Fitness Score': 1380.5735556690834}
# Metrics for symbol BALKRISIND.NS:
# {'Best Parameters': [2, 20, 3, 3, 3], 'Best Fitness Score': 11607.139960937511}
# Metrics for symbol BANDHANBNK.NS:
# {'Best Parameters': [5, 10, 10, 19, -0.9827165085967932], 'Best Fitness Score': 20287.5}
# Metrics for symbol BANKBARODA.NS:
# {'Best Parameters': [2, 4, 5, 12, -0.9966623718459241], 'Best Fitness Score': 23467.6646639141}
# Metrics for symbol BEL.NS:
# {'Best Parameters': [2, 5, 9, 15, -0.9726933439355497], 'Best Fitness Score': 1065.3411331176758}
# Metrics for symbol BHARATFORG.NS:
# {'Best Parameters': [2, 4, 3, 9, -0.9937464219911395], 'Best Fitness Score': 4050.2413083930815}
# Metrics for symbol BHARTIARTL.NS:
# {'Best Parameters': [10, 11, 8, 8, 1.7409298671372944], 'Best Fitness Score': 5627.115167389527}
# Metrics for symbol BHEL.NS:
# {'Best Parameters': [2, 9, 9, 18, -0.9930604812498026], 'Best Fitness Score': 35740.789306640625}
# Metrics for symbol BOSCHLTD.NS:
# {'Best Parameters': [6, 7, 8, 6, -0.7248716352084561], 'Best Fitness Score': 4503.802734375}
# Metrics for symbol BPCL.NS:
# {'Best Parameters': [2, 3, 9, 14, -0.9930604812498026], 'Best Fitness Score': 4202.39501953125}
# Metrics for symbol BRITANNIA.NS:
# {'Best Parameters': [10, 20, 5, 5, 3], 'Best Fitness Score': 19409.082363281246}
# Metrics for symbol GAIL.NS:
# {'Best Parameters': [2, 4, 8, 14, -0.9930604812498026], 'Best Fitness Score': 6290.8836983402725}
# Metrics for symbol GLENMARK.NS:
# {'Best Parameters': [6, 6, 7, 20, -0.8964251209314001], 'Best Fitness Score': 0}
# Metrics for symbol BSOFT.NS:
# {'Best Parameters': [2, 7, 9, 15, -0.9930604812498026], 'Best Fitness Score': 11255.804077148438}
# Metrics for symbol CANBK.NS:
# {'Best Parameters': [10, 12, 6, 9, -0.7260686877862257], 'Best Fitness Score': 50791.515182149065}
# Metrics for symbol CANFINHOME.NS:
# {'Best Parameters': [4, 10, 6, 18, -0.9945236709047033], 'Best Fitness Score': 11235.765812292804}
# Metrics for symbol CHAMBLFERT.NS:
# {'Best Parameters': [3, 20, 10, 19, -0.9085997275814534], 'Best Fitness Score': 10156.459712569851}
# Metrics for symbol CHOLAFIN.NS:
# {'Best Parameters': [2, 14, 2, 10, -0.936907537873025], 'Best Fitness Score': 7088.9022216796875}
# Metrics for symbol CIPLA.NS:
# {'Best Parameters': [8, 8, 5, 15, -0.2803624307634186], 'Best Fitness Score': 0}
# Metrics for symbol COALINDIA.NS:
# {'Best Parameters': [2, 15, 6, 14, -0.9932176635497952], 'Best Fitness Score': 2675.6273576645335}
# Metrics for symbol CONCOR.NS:
# {'Best Parameters': [4, 9, 7, 16, -0.9575102027854295], 'Best Fitness Score': 3864.5958251953125}
# Metrics for symbol COROMANDEL.NS:
# {'Best Parameters': [2, 10, 7, 18, -0.9574402313280936], 'Best Fitness Score': 7285.772857811744}
# Metrics for symbol CROMPTON.NS:
# {'Best Parameters': [2, 5, 10, 18, -0.8812108416198017], 'Best Fitness Score': 1039.8808027840778}
# Metrics for symbol CUB.NS:
# {'Best Parameters': [3, 17, 8, 15, -0.8570972465740695], 'Best Fitness Score': 4308.637351982372}
# Metrics for symbol DALBHARAT.NS:
# {'Best Parameters': [2, 10, 5, 12, -0.9659758702061141], 'Best Fitness Score': 13512.0}
# Metrics for symbol DELTACORP.NS:
# {'Best Parameters': [2, 10, 8, 14, -0.9930604812498026], 'Best Fitness Score': 1458.9975459959878}
# Metrics for symbol DIXON.NS:
# {'Best Parameters': [10, 14, 6, 9, -0.8358717922724077], 'Best Fitness Score': 7227.9896963058945}
# Metrics for symbol EXIDEIND.NS:
# {'Best Parameters': [2, 15, 3, 3, 3], 'Best Fitness Score': 23007.3602142334}
# Metrics for symbol IGL.NS:
# {'Best Parameters': [5, 9, 3, 15, -0.9959343084197383], 'Best Fitness Score': 2893.842683897574}
# Metrics for symbol GMRINFRA.NS:
# {'Best Parameters': [2, 6, 3, 15, -0.9930604812498026], 'Best Fitness Score': 26322.0}
# Metrics for symbol GNFC.NS:
# {'Best Parameters': [4, 8, 2, 18, 1.401522020601933], 'Best Fitness Score': 2567.0166015625}
# Metrics for symbol GRANULES.NS:
# {'Best Parameters': [10, 16, 8, 11, -0.9257767915322589], 'Best Fitness Score': 577.8058776855469}
# Metrics for symbol GRASIM.NS:
# {'Best Parameters': [3, 5, 7, 11, -0.8875365577906095], 'Best Fitness Score': 9735.867035868196}
# Metrics for symbol GUJGASLTD.NS:
# {'Best Parameters': [5, 12, 8, 18, -0.917178180915096], 'Best Fitness Score': 7101.598388671875}
# Metrics for symbol HCLTECH.NS:
# {'Best Parameters': [3, 4, 3, 3, 1.7587750010198437], 'Best Fitness Score': 23600.27623372474}
# Metrics for symbol HDFCAMC.NS:
# {'Best Parameters': [2, 17, 7, 16, 1.8802960980886212], 'Best Fitness Score': 8734.402587890625}
# Metrics for symbol HDFCLIFE.NS:
# {'Best Parameters': [2, 18, 9, 14, -0.9930604812498026], 'Best Fitness Score': 11844.602783203125}
# Metrics for symbol INDUSTOWER.NS:
# {'Best Parameters': [10, 18, 2, 16, -0.9962319673405025], 'Best Fitness Score': 7367.004852294922}
# Metrics for symbol HINDALCO.NS:
# {'Best Parameters': [3, 14, 3, 3, 3], 'Best Fitness Score': 20242.023114624022}
# Metrics for symbol AMBUJACEM.NS:
# {'Best Parameters': [10, 20, 3, 15, -0.9801429045411404], 'Best Fitness Score': 11318.197699480836}
# Metrics for symbol BATAINDIA.NS:
# {'Best Parameters': [6, 14, 5, 16, -0.9139156245035801], 'Best Fitness Score': 39.053466796875}
# Metrics for symbol ASHOKLEY.NS:
# {'Best Parameters': [2, 11, 7, 11, -0.8162673558658085], 'Best Fitness Score': 1331.9670570226247}
# Metrics for symbol HINDCOPPER.NS:
# {'Best Parameters': [3, 5, 8, 12, -0.9930604812498026], 'Best Fitness Score': 8252.739547888852}
# Metrics for symbol HINDPETRO.NS:
# {'Best Parameters': [10, 19, 4, 20, -0.9192811970255624], 'Best Fitness Score': 16640.99868774414}
# Metrics for symbol ICICIBANK.NS:
# {'Best Parameters': [2, 18, 7, 14, -0.9930604812498026], 'Best Fitness Score': 5462.392290828195}
# Metrics for symbol ICICIGI.NS:
# {'Best Parameters': [2, 19, 4, 7, -0.9930604812498026], 'Best Fitness Score': 11681.549841582158}
# Metrics for symbol ICICIPRULI.NS:
# {'Best Parameters': [9, 9, 4, 15, -0.861920360810749], 'Best Fitness Score': 0}
# Metrics for symbol IDEA.NS:
# {'Best Parameters': [3, 3, 4, 12, 1.7076220326211242], 'Best Fitness Score': 0}
# Metrics for symbol IDFC.NS:
# {'Best Parameters': [7, 8, 5, 13, -0.9953654016113052], 'Best Fitness Score': 5382.743529819343}
# Metrics for symbol IEX.NS:
# {'Best Parameters': [3, 17, 5, 12, -0.9878984355639909], 'Best Fitness Score': 1653.4261263087167}
# Metrics for symbol AUROPHARMA.NS:
# {'Best Parameters': [6, 9, 7, 5, -0.8458005588114631], 'Best Fitness Score': 449.75}
# Metrics for symbol INDHOTEL.NS:
# {'Best Parameters': [2, 14, 7, 8, -0.9150364475073512], 'Best Fitness Score': 7203.78678553}
# Metrics for symbol METROPOLIS.NS:
# {'Best Parameters': [2, 4, 4, 18, -0.982122934787669], 'Best Fitness Score': 4069.0497190192673}
# Metrics for symbol BIOCON.NS:
# {'Best Parameters': [10, 17, 6, 14, -0.9810924717193299], 'Best Fitness Score': 2037.1235421396714}
# Metrics for symbol MUTHOOTFIN.NS:
# {'Best Parameters': [3, 6, 5, 18, -0.9710813392347158], 'Best Fitness Score': 3739.1953125}
# Metrics for symbol INDIACEM.NS:
# {'Best Parameters': [3, 5, 2, 13, -0.9917972667111506], 'Best Fitness Score': 7483.867692197511}
# Metrics for symbol COLPAL.NS:
# {'Best Parameters': [2, 11, 10, 20, -0.9930604812498026], 'Best Fitness Score': 1206.4567472308966}
# Metrics for symbol PERSISTENT.NS:
# {'Best Parameters': [5, 8, 5, 14, -0.9518307709633383], 'Best Fitness Score': 9158.70344677099}
# Metrics for symbol INDIAMART.NS:
# {'Best Parameters': [2, 3, 3, 11, -0.8723931352713565], 'Best Fitness Score': 1446.4500327828482}
# Metrics for symbol INDUSINDBK.NS:
# {'Best Parameters': [10, 17, 5, 18, -0.9930604812498026], 'Best Fitness Score': 7780.441472614766}
# Metrics for symbol IRCTC.NS:
# {'Best Parameters': [10, 10, 7, 10, 0.12772879333007836], 'Best Fitness Score': 0}
# Metrics for symbol JINDALSTEL.NS:
# {'Best Parameters': [2, 6, 6, 14, -0.9930604812498026], 'Best Fitness Score': 8740.82318998546}
# Metrics for symbol JKCEMENT.NS:
# {'Best Parameters': [10, 18, 2, 2, -0.7741053708590071], 'Best Fitness Score': 31370.10498046875}
# Metrics for symbol JSWSTEEL.NS:
# {'Best Parameters': [4, 18, 3, 3, 3], 'Best Fitness Score': 16445.93806213379}
# Metrics for symbol JUBLFOOD.NS:
# {'Best Parameters': [3, 3, 7, 15, 0.762041391067857], 'Best Fitness Score': 0}
# Metrics for symbol DIVISLAB.NS:
# {'Best Parameters': [2, 3, 2, 14, -0.9983069683843241], 'Best Fitness Score': 4905.117792054309}
# Metrics for symbol KOTAKBANK.NS:
# {'Best Parameters': [9, 18, 10, 16, -0.7658478856473602], 'Best Fitness Score': 8415.0}
# Metrics for symbol L&TFH.NS:
# {'Best Parameters': [2, 8, 10, 13, -0.9699462920155235], 'Best Fitness Score': 23062.20295715332}
# Metrics for symbol LALPATHLAB.NS:
# {'Best Parameters': [2, 3, 9, 17, -0.9508302982852898], 'Best Fitness Score': 6075.09228515625}
# Metrics for symbol LAURUSLABS.NS:
# {'Best Parameters': [3, 2, 3, 20, -0.9649559765610982], 'Best Fitness Score': 416.40423583984375}
# Metrics for symbol SHRIRAMFIN.NS:
# {'Best Parameters': [5, 17, 8, 19, -0.9840651417413495], 'Best Fitness Score': 5069.318748947444}
# Metrics for symbol LICHSGFIN.NS:
# {'Best Parameters': [3, 17, 8, 13, -0.9360223704856643], 'Best Fitness Score': 13728.964732767989}
# Metrics for symbol LTIM.NS:
# {'Best Parameters': [7, 17, 8, 17, -0.8816801624224031], 'Best Fitness Score': 2053.90673828125}
# Metrics for symbol DLF.NS:
# {'Best Parameters': [2, 11, 8, 19, -0.9930604812498026], 'Best Fitness Score': 3942.8499514295836}
# Metrics for symbol LTTS.NS:
# {'Best Parameters': [2, 18, 3, 3, 3], 'Best Fitness Score': 17234.94012695313}
# Metrics for symbol LUPIN.NS:
# {'Best Parameters': [2, 3, 8, 14, -0.9930604812498026], 'Best Fitness Score': 1275.8925058655052}
# Metrics for symbol DRREDDY.NS:
# {'Best Parameters': [2, 3, 7, 10, -0.9380243566324198], 'Best Fitness Score': 740.8564453125}
# Metrics for symbol MANAPPURAM.NS:
# {'Best Parameters': [2, 15, 3, 3, 3], 'Best Fitness Score': 21118.010404205328}
# Metrics for symbol FEDERALBNK.NS:
# {'Best Parameters': [6, 8, 8, 18, -0.9930604812498026], 'Best Fitness Score': 3122.21560239233}
# Metrics for symbol TRENT.NS:
# {'Best Parameters': [2, 4, 6, 14, -0.9930604812498026], 'Best Fitness Score': 8495.547729492188}
# Metrics for symbol MARUTI.NS:
# {'Best Parameters': [6, 18, 7, 8, -0.994264811349302], 'Best Fitness Score': 6838.749385937777}
# Metrics for symbol MCX.NS:
# {'Best Parameters': [2, 7, 7, 12, -0.9930604812498026], 'Best Fitness Score': 6570.90478515625}
# Metrics for symbol MFSL.NS:
# {'Best Parameters': [5, 8, 6, 13, -0.9943421175557406], 'Best Fitness Score': 7020.0}
# Metrics for symbol MGL.NS:
# {'Best Parameters': [2, 6, 6, 9, -0.9930604812498026], 'Best Fitness Score': 2057.794589423108}
# Metrics for symbol MOTHERSON.NS:
# {'Best Parameters': [8, 18, 8, 14, -0.9709184019598378], 'Best Fitness Score': 16071.324031799057}
# Metrics for symbol MPHASIS.NS:
# {'Best Parameters': [7, 18, 4, 13, -0.9958112725959202], 'Best Fitness Score': 1326.6882736221305}
# Metrics for symbol MRF.NS:
# {'Best Parameters': [2, 15, 3, 3, 3], 'Best Fitness Score': 8444.289609375002}
# Metrics for symbol NATIONALUM.NS:
# {'Best Parameters': [4, 14, 8, 8, 1.941072897283986], 'Best Fitness Score': 10976.888808163418}
# Metrics for symbol NESTLEIND.NS:
# {'Best Parameters': [2, 19, 3, 3, 3], 'Best Fitness Score': 5965.960546874994}
# Metrics for symbol NMDC.NS:
# {'Best Parameters': [2, 8, 2, 18, 1.0740379848302624], 'Best Fitness Score': 14531.013466616017}
# Metrics for symbol NTPC.NS:
# {'Best Parameters': [10, 15, 10, 16, -0.9551388373814385], 'Best Fitness Score': 874.6525421142578}
# Metrics for symbol HAL.NS:
# {'Best Parameters': [9, 15, 3, 18, -0.8277485611043467], 'Best Fitness Score': 6721.555908203125}
# Metrics for symbol OBEROIRLTY.NS:
# {'Best Parameters': [3, 4, 3, 12, -0.9930604812498026], 'Best Fitness Score': 8994.973585020496}
# Metrics for symbol HEROMOTOCO.NS:
# {'Best Parameters': [5, 13, 9, 9, 1.9117064983849055], 'Best Fitness Score': 3470.4226374614873}
# Metrics for symbol OFSS.NS:
# {'Best Parameters': [3, 9, 5, 5, 1.947532150147524], 'Best Fitness Score': 5246.5623253631475}
# Metrics for symbol ONGC.NS:
# {'Best Parameters': [2, 3, 9, 18, -0.9930604812498026], 'Best Fitness Score': 6618.0}
# Metrics for symbol PEL.NS:
# {'Best Parameters': [2, 18, 3, 3, 3], 'Best Fitness Score': 4696.156780395505}
# Metrics for symbol PETRONET.NS:
# {'Best Parameters': [3, 5, 8, 5, -0.8996531367140556], 'Best Fitness Score': 4117.246293691119}
# Metrics for symbol PIDILITIND.NS:
# {'Best Parameters': [9, 20, 4, 16, -0.9482598224483397], 'Best Fitness Score': 3405.1956565083624}
# Metrics for symbol PIIND.NS:
# {'Best Parameters': [3, 4, 8, 14, -0.9930604812498026], 'Best Fitness Score': 2190.297607421875}
# Metrics for symbol IDFCFIRSTB.NS:
# {'Best Parameters': [2, 4, 8, 18, -0.9930604812498026], 'Best Fitness Score': 6705.295127868652}
# Metrics for symbol PNB.NS:
# {'Best Parameters': [8, 20, 5, 9, -0.8352217807384327], 'Best Fitness Score': 38000.26560226126}
# Metrics for symbol POLYCAB.NS:
# {'Best Parameters': [2, 5, 3, 14, -0.9930604812498026], 'Best Fitness Score': 15296.864708338653}
# Metrics for symbol PVRINOX.NS:
# {'Best Parameters': [3, 7, 7, 16, -0.9186121096389289], 'Best Fitness Score': 1974.62059024694}
# Metrics for symbol RAMCOCEM.NS:
# {'Best Parameters': [3, 6, 4, 15, -0.9055323516088739], 'Best Fitness Score': 15457.89901911779}
# Metrics for symbol RBLBANK.NS:
# {'Best Parameters': [2, 3, 7, 12, -0.9930604812498026], 'Best Fitness Score': 10338.999842692168}
# Metrics for symbol RECLTD.NS:
# {'Best Parameters': [6, 20, 3, 3, 1.7955857837190372], 'Best Fitness Score': 25109.301275069804}
# Metrics for symbol RELIANCE.NS:
# {'Best Parameters': [3, 17, 6, 14, -0.9930604812498026], 'Best Fitness Score': 5031.851215050965}
# Metrics for symbol IPCALAB.NS:
# {'Best Parameters': [6, 19, 3, 8, -0.9243880983879914], 'Best Fitness Score': 1079.9071520607858}
# Metrics for symbol SAIL.NS:
# {'Best Parameters': [2, 7, 9, 10, -0.9930604812498026], 'Best Fitness Score': 6866.683888260583}
# Metrics for symbol ITC.NS:
# {'Best Parameters': [2, 7, 3, 15, -0.9927241736497228], 'Best Fitness Score': 2373.396424804671}
# Metrics for symbol SBICARD.NS:
# {'Best Parameters': [2, 16, 8, 14, -0.9930604812498026], 'Best Fitness Score': 5083.076100985309}
# Metrics for symbol SBILIFE.NS:
# {'Best Parameters': [3, 6, 2, 10, -0.9306112872581751], 'Best Fitness Score': 4172.19775390625}
# Metrics for symbol SBIN.NS:
# {'Best Parameters': [2, 17, 3, 3, 3], 'Best Fitness Score': 15389.458419799805}
# Metrics for symbol SHREECEM.NS:
# {'Best Parameters': [9, 20, 5, 19, -0.5139872659663507], 'Best Fitness Score': 1612.5}
# Metrics for symbol SRF.NS:
# {'Best Parameters': [6, 8, 6, 20, 1.5367573551270057], 'Best Fitness Score': 2241.2476025782303}
# Metrics for symbol SUNTV.NS:
# {'Best Parameters': [6, 8, 8, 9, -0.9930604812498026], 'Best Fitness Score': 7142.101623535156}
# Metrics for symbol SYNGENE.NS:
# {'Best Parameters': [7, 13, 4, 5, -0.9446947714007445], 'Best Fitness Score': 7226.139426815904}
# Metrics for symbol TATACHEM.NS:
# {'Best Parameters': [4, 5, 5, 19, -0.9930604812498026], 'Best Fitness Score': 480.99365234375}
# Metrics for symbol TATACOMM.NS:
# {'Best Parameters': [8, 8, 9, 10, 0.0719816138017082], 'Best Fitness Score': 0}
# Metrics for symbol TATACONSUM.NS:
# {'Best Parameters': [10, 20, 4, 18, -0.7814994748260597], 'Best Fitness Score': 7042.689238799443}
# Metrics for symbol TATAMOTORS.NS:
# {'Best Parameters': [8, 13, 8, 15, -0.9938783667791403], 'Best Fitness Score': 665.0517272949219}
# Metrics for symbol TATAPOWER.NS:
# {'Best Parameters': [6, 17, 2, 18, -0.9630121775620725], 'Best Fitness Score': 1166.3030693045157}
# Metrics for symbol TATASTEEL.NS:
# {'Best Parameters': [3, 11, 3, 3, 3], 'Best Fitness Score': 12688.142033386237}
# Metrics for symbol TCS.NS:
# {'Best Parameters': [2, 15, 3, 3, 3], 'Best Fitness Score': 9204.24408203125}
# Metrics for symbol TECHM.NS:
# {'Best Parameters': [2, 18, 7, 14, -0.9930604812498026], 'Best Fitness Score': 1989.695068359375}
# Metrics for symbol TITAN.NS:
# {'Best Parameters': [7, 5, 10, 10, -0.930680040149782], 'Best Fitness Score': 742.052490234375}
# Metrics for symbol TORNTPHARM.NS:
# {'Best Parameters': [9, 18, 8, 8, -0.8676844498294191], 'Best Fitness Score': 1460.0}
# Metrics for symbol TVSMOTOR.NS:
# {'Best Parameters': [3, 4, 3, 16, -0.9930604812498026], 'Best Fitness Score': 3232.1120817937963}
# Metrics for symbol UBL.NS:
# {'Best Parameters': [3, 6, 2, 14, -0.9930604812498026], 'Best Fitness Score': 9576.005859375}
# Metrics for symbol ULTRACEMCO.NS:
# {'Best Parameters': [4, 17, 6, 9, -0.9499601382087174], 'Best Fitness Score': 2440.0}
# Metrics for symbol UPL.NS:
# {'Best Parameters': [10, 18, 3, 3, 3], 'Best Fitness Score': 16781.593856811523}
# Metrics for symbol VEDL.NS:
# {'Best Parameters': [10, 20, 8, 13, -0.9807549078810394], 'Best Fitness Score': 5393.3978271484375}
# Metrics for symbol WIPRO.NS:
# {'Best Parameters': [8, 19, 6, 6, 1.1450805883272785], 'Best Fitness Score': 3390.422041386988}
# Metrics for symbol ZYDUSLIFE.NS:
# {'Best Parameters': [2, 6, 3, 3, 3], 'Best Fitness Score': 17647.306760253905}
# Metrics for symbol NAUKRI.NS:
# {'Best Parameters': [5, 16, 5, 13, -0.9930604812498026], 'Best Fitness Score': 4193.228668112984}
# Metrics for symbol NAVINFLUOR.NS:
# {'Best Parameters': [2, 6, 6, 20, -0.9930604812498026], 'Best Fitness Score': 1451.607421875}
# Metrics for symbol M&MFIN.NS:
# {'Best Parameters': [2, 6, 8, 18, -0.9494169885593725], 'Best Fitness Score': 30559.205810546875}
# Metrics for symbol MARICO.NS:
# {'Best Parameters': [2, 7, 3, 8, -0.9847777676237477], 'Best Fitness Score': 11447.353454589844}
# Metrics for symbol PFC.NS:
# {'Best Parameters': [9, 19, 6, 8, -0.9929625183244685], 'Best Fitness Score': 50626.68880325025}
# Metrics for symbol AARTIIND.NS:
# {'Best Parameters': [5, 6, 8, 14, -0.9930604812498026], 'Best Fitness Score': 1855.2474975585938}
# Metrics for symbol ASIANPAINT.NS:
# {'Best Parameters': [2, 16, 10, 13, -0.9930604812498026], 'Best Fitness Score': 5095.23427487644}
# Metrics for symbol ATUL.NS:
# {'Best Parameters': [4, 11, 4, 14, -0.9782749934913276], 'Best Fitness Score': 4431.169993195093}
# Metrics for symbol SUNPHARMA.NS:
# {'Best Parameters': [5, 6, 9, 20, -0.7919943254620427], 'Best Fitness Score': 3976.273154196556}
# Metrics for symbol CUMMINSIND.NS:
# {'Best Parameters': [5, 9, 7, 10, -0.8991873117398745], 'Best Fitness Score': 12545.405029296875}
# Metrics for symbol DABUR.NS:
# {'Best Parameters': [2, 10, 8, 15, -0.9930604812498026], 'Best Fitness Score': 12311.358725224192}
# Metrics for symbol DEEPAKNTR.NS:
# {'Best Parameters': [2, 5, 2, 14, -0.9906931190113242], 'Best Fitness Score': 8547.833624156374}
# Metrics for symbol EICHERMOT.NS:
# {'Best Parameters': [2, 16, 2, 17, -0.9426121755010877], 'Best Fitness Score': 338.7978515625}
# Metrics for symbol ZEEL.NS:
# {'Best Parameters': [3, 4, 8, 12, -0.9930604812498026], 'Best Fitness Score': 7458.903228759766}
# Metrics for symbol ESCORTS.NS:
# {'Best Parameters': [2, 13, 10, 14, -0.9453905017564037], 'Best Fitness Score': 20978.75}
# Metrics for symbol GODREJCP.NS:
# {'Best Parameters': [8, 20, 9, 13, 1.7268981800923076], 'Best Fitness Score': 9327.153442382812}
# Metrics for symbol GODREJPROP.NS:
# {'Best Parameters': [5, 8, 6, 6, -0.9898901974746763], 'Best Fitness Score': 1535.234710062161}
# Metrics for symbol HAVELLS.NS:
# {'Best Parameters': [9, 13, 10, 18, -0.9362821838667623], 'Best Fitness Score': 2559.5947265625}
# Metrics for symbol HDFCBANK.NS:
# {'Best Parameters': [2, 15, 3, 3, 3], 'Best Fitness Score': 12513.603515625}
# Metrics for symbol INDIGO.NS:
# {'Best Parameters': [6, 18, 6, 12, -0.9851744305605199], 'Best Fitness Score': 18657.59619140625}
# Metrics for symbol INFY.NS:
# {'Best Parameters': [7, 17, 3, 3, 1.9994814376764105], 'Best Fitness Score': 14858.448636767818}
# Metrics for symbol IOC.NS:
# {'Best Parameters': [5, 19, 3, 3, 1.394054873120532], 'Best Fitness Score': 14908.832418477847}
# Metrics for symbol BERGEPAINT.NS:
# {'Best Parameters': [8, 17, 9, 19, -0.8447087957054135], 'Best Fitness Score': 4967.993408203125}
# Metrics for symbol LT.NS:
# {'Best Parameters': [5, 13, 3, 3, 1.7245907467477304], 'Best Fitness Score': 16761.878245037173}
# Metrics for symbol MCDOWELL-N.NS:
# {'Best Parameters': [2, 4, 8, 5, -0.9930604812498026], 'Best Fitness Score': 9544.802001953125}
# Metrics for symbol IBULHSGFIN.NS:
# {'Best Parameters': [2, 8, 8, 20, -0.9930604812498026], 'Best Fitness Score': 2382.590241124563}
# Metrics for symbol M&M.NS:
# {'Best Parameters': [10, 12, 9, 18, -0.6764834589457597], 'Best Fitness Score': 2059.4671674599795}
# Metrics for symbol PAGEIND.NS:
# {'Best Parameters': [2, 4, 9, 14, -0.9930604812498026], 'Best Fitness Score': 1299.9121744392032}
# Metrics for symbol SIEMENS.NS:
# {'Best Parameters': [2, 12, 2, 14, -0.9930604812498026], 'Best Fitness Score': 11271.46858822443}
# Metrics for symbol COFORGE.NS:
# {'Best Parameters': [2, 18, 10, 18, -0.9930604812498026], 'Best Fitness Score': 5002.960334537029}
# Metrics for symbol HINDUNILVR.NS:
# {'Best Parameters': [2, 18, 8, 19, -0.9930604812498026], 'Best Fitness Score': 11431.702392578125}
# Metrics for symbol POWERGRID.NS:
# {'Best Parameters': [7, 20, 7, 19, -0.9751264270028611], 'Best Fitness Score': 684.9069671630859}
# Metrics for symbol VOLTAS.NS:
# {'Best Parameters': [7, 18, 6, 16, -0.9259203279308994], 'Best Fitness Score': 3776.0097749270167}

# %%
# Out:
# {'ITC.NS': {'Best Parameters': [2, 7, 4, 13, -0.9930604812498026],
#   'Best Fitness Score': 2373.946841134861},
#  'SBIN.NS': {'Best Parameters': [2, 18, 3, 3, 3],
#   'Best Fitness Score': 15389.458419799805},
#  'BPCL.NS': {'Best Parameters': [10, 20, 8, 10, -0.8565579477209035],
#   'Best Fitness Score': 15380.65718669643},
#  'IGL.NS': {'Best Parameters': [4, 12, 8, 19, -0.9930604812498026],
#   'Best Fitness Score': 2972.4693412705237}}

# %%
# Print metrics for all symbols
for symbol, metrics in all_metrics.items():


    best_parameters = metrics['Best Parameters']# dlf 1year

    test_data = yf.download(symbol,start='2023-01-01',end='2024-01-08')

    # Apply the strategy on out-of-sample data using the best parameters
    out_of_sample_profit = evaluate_strategy(test_data.copy(), *best_parameters)


    # Print or analyze the performance metrics
    print(symbol)
    print("Out-of-sample profit:", out_of_sample_profit)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# BALRAMCHIN.NS
# Out-of-sample profit: [7474.0, 28, 22, 21, 0.7857142857142857, 163806.89077114913]
# [*********************100%%**********************]  1 of 1 completed
# ACC.NS
# Out-of-sample profit: [10713.851196289062, 11, 5, 5, 0.45454545454545453, 101363.07679266694]
# [*********************100%%**********************]  1 of 1 completed
# ABB.NS
# Out-of-sample profit: [11779.498908563992, 21, 15, 15, 0.7142857142857143, 164195.9306619435]
# [*********************100%%**********************]  1 of 1 completed
# ALKEM.NS
# Out-of-sample profit: [1173.0, 30, 22, 22, 0.7333333333333333, 180080.16206248096]
# [*********************100%%**********************]  1 of 1 completed
# ABBOTINDIA.NS
# Out-of-sample profit: [801.25, 30, 19, 18, 0.6333333333333333, 130209.23149631849]
# [*********************100%%**********************]  1 of 1 completed
# ABCAPITAL.NS
# Out-of-sample profit: [-1105.1971893310547, 27, 19, 19, 0.7037037037037037, 152065.16281319933]
# [*********************100%%**********************]  1 of 1 completed
# ABFRL.NS
# Out-of-sample profit: [10340.0, 16, 13, 13, 0.8125, 121559.31229624525]
# [*********************100%%**********************]  1 of 1 completed
# ADANIENT.NS
# Out-of-sample profit: [-930.045654296875, 36, 24, 24, 0.6666666666666666, 255953.66896022152]
# [*********************100%%**********************]  1 of 1 completed
# ADANIPORTS.NS
# Out-of-sample profit: [33118.113203125, 12, 6, 6, 0.5, 157526.04756286624]
# [*********************100%%**********************]  1 of 1 completed
# APOLLOHOSP.NS
# Out-of-sample profit: [-1254.0, 12, 8, 8, 0.6666666666666666, 126615.3850435142]
# [*********************100%%**********************]  1 of 1 completed
# APOLLOTYRE.NS
# Out-of-sample profit: [3937.857537052111, 21, 15, 15, 0.7142857142857143, 145964.8790155168]
# [*********************100%%**********************]  1 of 1 completed
# ASTRAL.NS
# Out-of-sample profit: [-792.654052734375, 27, 19, 19, 0.7037037037037037, 158131.4340138925]
# [*********************100%%**********************]  1 of 1 completed
# AUBANK.NS
# Out-of-sample profit: [1248.4944854170155, 17, 9, 8, 0.5294117647058824, 127659.77498817664]
# [*********************100%%**********************]  1 of 1 completed
# AXISBANK.NS
# Out-of-sample profit: [-984.5523681640625, 21, 7, 7, 0.3333333333333333, 107410.43349498602]
# [*********************100%%**********************]  1 of 1 completed
# BAJAJ-AUTO.NS
# Out-of-sample profit: [-665.7041015625, 16, 9, 9, 0.5625, 141130.33694315684]
# [*********************100%%**********************]  1 of 1 completed
# BAJAJFINSV.NS
# Out-of-sample profit: [0, 0, 0, 0, 0, 100000]
# [*********************100%%**********************]  1 of 1 completed
# BAJFINANCE.NS
# Out-of-sample profit: [1789.2196996096254, 33, 25, 25, 0.7575757575757576, 144136.5774144406]
# [*********************100%%**********************]  1 of 1 completed
# BALKRISIND.NS
# Out-of-sample profit: [-2358.2017333984413, 12, 3, 3, 0.25, 89999.2185900879]
# [*********************100%%**********************]  1 of 1 completed
# BANDHANBNK.NS
# Out-of-sample profit: [1244.4045946541432, 18, 11, 11, 0.6111111111111112, 127981.14658393148]
# [*********************100%%**********************]  1 of 1 completed
# BANKBARODA.NS
# Out-of-sample profit: [887.5, 37, 26, 25, 0.7027027027027027, 169708.60679691698]
# [*********************100%%**********************]  1 of 1 completed
# BEL.NS
# Out-of-sample profit: [8910.0, 36, 27, 25, 0.75, 164741.43569506877]
# [*********************100%%**********************]  1 of 1 completed
# BHARATFORG.NS
# Out-of-sample profit: [3428.6645206271205, 37, 27, 27, 0.7297297297297297, 160581.50335691654]
# [*********************100%%**********************]  1 of 1 completed
# BHARTIARTL.NS
# Out-of-sample profit: [5626.020040510324, 9, 4, 4, 0.4444444444444444, 114828.54822299832]
# [*********************100%%**********************]  1 of 1 completed
# BHEL.NS
# Out-of-sample profit: [4215.4619579346545, 26, 20, 20, 0.7692307692307693, 221943.2851110631]
# [*********************100%%**********************]  1 of 1 completed
# BOSCHLTD.NS
# Out-of-sample profit: [12313.236522436855, 16, 14, 14, 0.875, 132819.90314258158]
# [*********************100%%**********************]  1 of 1 completed
# BPCL.NS
# Out-of-sample profit: [210.64532470703125, 34, 24, 22, 0.7058823529411765, 175018.95652078913]
# [*********************100%%**********************]  1 of 1 completed
# BRITANNIA.NS
# Out-of-sample profit: [6536.875932617187, 6, 2, 2, 0.3333333333333333, 114439.78870117188]
# [*********************100%%**********************]  1 of 1 completed
# GAIL.NS
# Out-of-sample profit: [16773.897542238294, 26, 22, 20, 0.8461538461538461, 196120.77820082707]
# [*********************100%%**********************]  1 of 1 completed
# GLENMARK.NS
# Out-of-sample profit: [0, 0, 0, 0, 0, 100000]
# [*********************100%%**********************]  1 of 1 completed
# BSOFT.NS
# Out-of-sample profit: [345.603515625, 27, 21, 20, 0.7777777777777778, 213972.28496137078]
# [*********************100%%**********************]  1 of 1 completed
# CANBK.NS
# Out-of-sample profit: [10377.623640828431, 10, 6, 5, 0.6, 133356.20834548882]
# [*********************100%%**********************]  1 of 1 completed
# CANFINHOME.NS
# Out-of-sample profit: [404.25201416015625, 19, 11, 11, 0.5789473684210527, 129271.23231784707]
# [*********************100%%**********************]  1 of 1 completed
# CHAMBLFERT.NS
# Out-of-sample profit: [2014.9014279979838, 16, 14, 14, 0.875, 150593.47202323287]
# [*********************100%%**********************]  1 of 1 completed
# CHOLAFIN.NS
# Out-of-sample profit: [13520.253295898438, 17, 12, 11, 0.7058823529411765, 163857.81316022662]
# [*********************100%%**********************]  1 of 1 completed
# CIPLA.NS
# Out-of-sample profit: [0, 0, 0, 0, 0, 100000]
# [*********************100%%**********************]  1 of 1 completed
# COALINDIA.NS
# Out-of-sample profit: [10261.894897460938, 20, 14, 14, 0.7, 162232.39084603806]
# [*********************100%%**********************]  1 of 1 completed
# CONCOR.NS
# Out-of-sample profit: [15497.462722465443, 17, 9, 9, 0.5294117647058824, 135267.3827053756]
# [*********************100%%**********************]  1 of 1 completed
# COROMANDEL.NS
# Out-of-sample profit: [481.2469482421875, 24, 20, 19, 0.8333333333333334, 158021.75264607702]
# [*********************100%%**********************]  1 of 1 completed
# CROMPTON.NS
# Out-of-sample profit: [3176.0, 31, 24, 23, 0.7741935483870968, 126799.51155724472]
# [*********************100%%**********************]  1 of 1 completed
# CUB.NS
# Out-of-sample profit: [5455.734751830256, 13, 8, 8, 0.6153846153846154, 133094.1632543642]
# [*********************100%%**********************]  1 of 1 completed
# DALBHARAT.NS
# Out-of-sample profit: [765.9072265625, 21, 15, 14, 0.7142857142857143, 180194.18642111748]
# [*********************100%%**********************]  1 of 1 completed
# DELTACORP.NS
# Out-of-sample profit: [6911.08233990632, 22, 14, 14, 0.6363636363636364, 135328.02631197797]
# [*********************100%%**********************]  1 of 1 completed
# DIXON.NS
# Out-of-sample profit: [25133.26500432466, 9, 7, 7, 0.7777777777777778, 196999.84536546882]
# [*********************100%%**********************]  1 of 1 completed
# EXIDEIND.NS
# Out-of-sample profit: [-3644.1313494873157, 13, 4, 4, 0.3076923076923077, 118055.7712944031]
# [*********************100%%**********************]  1 of 1 completed
# IGL.NS
# Out-of-sample profit: [183.29827880859375, 22, 12, 10, 0.5454545454545454, 115652.96713839666]
# [*********************100%%**********************]  1 of 1 completed
# GMRINFRA.NS
# Out-of-sample profit: [22256.79605102539, 27, 21, 21, 0.7777777777777778, 200582.17147841846]
# [*********************100%%**********************]  1 of 1 completed
# GNFC.NS
# Out-of-sample profit: [1732.7517700195312, 20, 7, 7, 0.35, 110690.1236933629]
# [*********************100%%**********************]  1 of 1 completed
# GRANULES.NS
# Out-of-sample profit: [14591.215577253412, 7, 4, 4, 0.5714285714285714, 142650.185427431]
# [*********************100%%**********************]  1 of 1 completed
# GRASIM.NS
# Out-of-sample profit: [341.690185546875, 24, 20, 19, 0.8333333333333334, 143388.016327796]
# [*********************100%%**********************]  1 of 1 completed
# GUJGASLTD.NS
# Out-of-sample profit: [-271.7015075683594, 17, 6, 6, 0.35294117647058826, 111209.20278930664]
# [*********************100%%**********************]  1 of 1 completed
# HCLTECH.NS
# Out-of-sample profit: [5418.9019775390625, 17, 10, 10, 0.5882352941176471, 116259.76207751816]
# [*********************100%%**********************]  1 of 1 completed
# HDFCAMC.NS
# Out-of-sample profit: [4377.59814453125, 18, 8, 8, 0.4444444444444444, 124698.14889766788]
# [*********************100%%**********************]  1 of 1 completed
# HDFCLIFE.NS
# Out-of-sample profit: [-523.8023681640625, 21, 10, 10, 0.47619047619047616, 125581.40182380748]
# [*********************100%%**********************]  1 of 1 completed
# INDUSTOWER.NS
# Out-of-sample profit: [1183.5176184454913, 10, 6, 6, 0.6, 120042.76938897929]
# [*********************100%%**********************]  1 of 1 completed
# HINDALCO.NS
# Out-of-sample profit: [-3157.870459899902, 10, 3, 3, 0.3, 102312.80088226321]
# [*********************100%%**********************]  1 of 1 completed
# AMBUJACEM.NS
# Out-of-sample profit: [21831.594221387884, 9, 7, 7, 0.7777777777777778, 145858.53522888548]
# [*********************100%%**********************]  1 of 1 completed
# BATAINDIA.NS
# Out-of-sample profit: [506.302978515625, 16, 7, 7, 0.4375, 103716.04789918108]
# [*********************100%%**********************]  1 of 1 completed
# ASHOKLEY.NS
# Out-of-sample profit: [5997.177333475416, 24, 17, 15, 0.7083333333333334, 145785.91812432825]
# [*********************100%%**********************]  1 of 1 completed
# HINDCOPPER.NS
# Out-of-sample profit: [75252.96510103294, 22, 15, 15, 0.6818181818181818, 272123.6189764609]
# [*********************100%%**********************]  1 of 1 completed
# HINDPETRO.NS
# Out-of-sample profit: [1609.4332529350158, 13, 5, 5, 0.38461538461538464, 148537.32787770435]
# [*********************100%%**********************]  1 of 1 completed
# ICICIBANK.NS
# Out-of-sample profit: [13071.490478515625, 17, 14, 14, 0.8235294117647058, 134720.66812148216]
# [*********************100%%**********************]  1 of 1 completed
# ICICIGI.NS
# Out-of-sample profit: [510.404296875, 22, 16, 16, 0.7272727272727273, 127362.01076040529]
# [*********************100%%**********************]  1 of 1 completed
# ICICIPRULI.NS
# Out-of-sample profit: [0, 0, 0, 0, 0, 100000]
# [*********************100%%**********************]  1 of 1 completed
# IDEA.NS
# Out-of-sample profit: [0, 0, 0, 0, 0, 100000]
# [*********************100%%**********************]  1 of 1 completed
# IDFC.NS
# Out-of-sample profit: [-98.49849700927734, 22, 16, 15, 0.7272727272727273, 124701.3907708843]
# [*********************100%%**********************]  1 of 1 completed
# IEX.NS
# Out-of-sample profit: [9158.312549727067, 14, 11, 10, 0.7857142857142857, 161241.26721094153]
# [*********************100%%**********************]  1 of 1 completed
# AUROPHARMA.NS
# Out-of-sample profit: [32384.481449130653, 14, 10, 10, 0.7142857142857143, 195520.5999469736]
# [*********************100%%**********************]  1 of 1 completed
# INDHOTEL.NS
# Out-of-sample profit: [343.3559875488281, 25, 14, 14, 0.56, 147489.6777408035]
# [*********************100%%**********************]  1 of 1 completed
# METROPOLIS.NS
# Out-of-sample profit: [-1227.14013671875, 31, 22, 22, 0.7096774193548387, 173431.6204556513]
# [*********************100%%**********************]  1 of 1 completed
# BIOCON.NS
# Out-of-sample profit: [135.60137939453125, 12, 6, 6, 0.5, 114555.71614369708]
# [*********************100%%**********************]  1 of 1 completed
# MUTHOOTFIN.NS
# Out-of-sample profit: [-667.397705078125, 28, 18, 17, 0.6428571428571429, 139601.32085919922]
# [*********************100%%**********************]  1 of 1 completed
# INDIACEM.NS
# Out-of-sample profit: [3639.75, 28, 18, 17, 0.6428571428571429, 170465.30484584346]
# [*********************100%%**********************]  1 of 1 completed
# COLPAL.NS
# Out-of-sample profit: [3068.1602140216783, 25, 23, 23, 0.92, 141521.56115379182]
# [*********************100%%**********************]  1 of 1 completed
# PERSISTENT.NS
# Out-of-sample profit: [20519.062953758435, 15, 10, 10, 0.6666666666666666, 166229.27022028016]
# [*********************100%%**********************]  1 of 1 completed
# INDIAMART.NS
# Out-of-sample profit: [1439.8674474610743, 37, 29, 29, 0.7837837837837838, 166776.8373912729]
# [*********************100%%**********************]  1 of 1 completed
# INDUSINDBK.NS
# Out-of-sample profit: [5099.1016845703125, 13, 6, 6, 0.46153846153846156, 108995.92382977968]
# [*********************100%%**********************]  1 of 1 completed
# IRCTC.NS
# Out-of-sample profit: [0, 0, 0, 0, 0, 100000]
# [*********************100%%**********************]  1 of 1 completed
# JINDALSTEL.NS
# Out-of-sample profit: [2817.0975952148438, 27, 19, 19, 0.7037037037037037, 146666.12515175933]
# [*********************100%%**********************]  1 of 1 completed
# JKCEMENT.NS
# Out-of-sample profit: [13127.263681912507, 11, 8, 8, 0.7272727272727273, 127465.10227217559]
# [*********************100%%**********************]  1 of 1 completed
# JSWSTEEL.NS
# Out-of-sample profit: [-3487.9679516601605, 8, 3, 3, 0.375, 112798.32763549805]
# [*********************100%%**********************]  1 of 1 completed
# JUBLFOOD.NS
# Out-of-sample profit: [0, 0, 0, 0, 0, 100000]
# [*********************100%%**********************]  1 of 1 completed
# DIVISLAB.NS
# Out-of-sample profit: [780.0, 35, 24, 23, 0.6857142857142857, 159647.9850161062]
# [*********************100%%**********************]  1 of 1 completed
# KOTAKBANK.NS
# Out-of-sample profit: [809.2224360283071, 12, 7, 7, 0.5833333333333334, 106845.96586555048]
# [*********************100%%**********************]  1 of 1 completed
# L&TFH.NS
# Out-of-sample profit: [290.5, 22, 19, 18, 0.8636363636363636, 185537.46763433298]
# [*********************100%%**********************]  1 of 1 completed
# LALPATHLAB.NS
# Out-of-sample profit: [-352.0, 39, 27, 24, 0.6923076923076923, 169455.44343732166]
# [*********************100%%**********************]  1 of 1 completed
# LAURUSLABS.NS
# Out-of-sample profit: [12711.669311525768, 42, 31, 30, 0.7380952380952381, 162518.4131737766]
# [*********************100%%**********************]  1 of 1 completed
# SHRIRAMFIN.NS
# Out-of-sample profit: [-3391.5, 16, 6, 6, 0.375, 118021.29932957239]
# [*********************100%%**********************]  1 of 1 completed
# LICHSGFIN.NS
# Out-of-sample profit: [14265.606445771104, 15, 8, 7, 0.5333333333333333, 133385.9237075569]
# [*********************100%%**********************]  1 of 1 completed
# LTIM.NS
# Out-of-sample profit: [12602.091796875, 10, 7, 7, 0.7, 134687.63253077545]
# [*********************100%%**********************]  1 of 1 completed
# DLF.NS
# Out-of-sample profit: [2745.0, 24, 21, 21, 0.875, 177475.3459455386]
# [*********************100%%**********************]  1 of 1 completed
# LTTS.NS
# Out-of-sample profit: [20625.794921875, 11, 4, 4, 0.36363636363636365, 130571.91748779296]
# [*********************100%%**********************]  1 of 1 completed
# LUPIN.NS
# Out-of-sample profit: [1633.9151521874978, 36, 29, 29, 0.8055555555555556, 166241.54576639668]
# [*********************100%%**********************]  1 of 1 completed
# DRREDDY.NS
# Out-of-sample profit: [6732.531519881445, 32, 27, 25, 0.84375, 149488.18414468953]
# [*********************100%%**********************]  1 of 1 completed
# MANAPPURAM.NS
# Out-of-sample profit: [-3619.5583749389602, 15, 6, 6, 0.4, 117055.69516708373]
# [*********************100%%**********************]  1 of 1 completed
# FEDERALBNK.NS
# Out-of-sample profit: [315.6072235107422, 22, 14, 14, 0.6363636363636364, 123609.15326157438]
# [*********************100%%**********************]  1 of 1 completed
# TRENT.NS
# Out-of-sample profit: [2182.5954960636627, 27, 23, 23, 0.8518518518518519, 222688.38750847089]
# [*********************100%%**********************]  1 of 1 completed
# MARUTI.NS
# Out-of-sample profit: [-1062.0, 9, 8, 8, 0.8888888888888888, 123553.92492708124]
# [*********************100%%**********************]  1 of 1 completed
# MCX.NS
# Out-of-sample profit: [1297.947509765625, 28, 19, 19, 0.6785714285714286, 163903.57554467715]
# [*********************100%%**********************]  1 of 1 completed
# MFSL.NS
# Out-of-sample profit: [17859.613005080784, 13, 7, 7, 0.5384615384615384, 145374.8160552167]
# [*********************100%%**********************]  1 of 1 completed
# MGL.NS
# Out-of-sample profit: [23294.448446678118, 24, 18, 17, 0.75, 186516.3944384944]
# [*********************100%%**********************]  1 of 1 completed
# MOTHERSON.NS
# Out-of-sample profit: [4746.086786098136, 13, 7, 7, 0.5384615384615384, 140492.14444570735]
# [*********************100%%**********************]  1 of 1 completed
# MPHASIS.NS
# Out-of-sample profit: [32033.40283203125, 7, 4, 4, 0.5714285714285714, 160445.64590799675]
# [*********************100%%**********************]  1 of 1 completed
# MRF.NS
# Out-of-sample profit: [32934.292109375005, 5, 1, 1, 0.2, 124870.257421875]
# [*********************100%%**********************]  1 of 1 completed
# NATIONALUM.NS
# Out-of-sample profit: [38969.83304675594, 15, 4, 4, 0.26666666666666666, 138920.75718143035]
# [*********************100%%**********************]  1 of 1 completed
# NESTLEIND.NS
# Out-of-sample profit: [-77477.3984375, 6, 2, 2, 0.3333333333333333, 30612.640800781242]
# [*********************100%%**********************]  1 of 1 completed
# NMDC.NS
# Out-of-sample profit: [1230.4577026367188, 22, 9, 9, 0.4090909090909091, 122236.70033224084]
# [*********************100%%**********************]  1 of 1 completed
# NTPC.NS
# Out-of-sample profit: [29797.89678955078, 12, 8, 8, 0.6666666666666666, 155636.0365022776]
# [*********************100%%**********************]  1 of 1 completed
# HAL.NS
# Out-of-sample profit: [64452.489056480175, 12, 9, 9, 0.75, 204165.02863342478]
# [*********************100%%**********************]  1 of 1 completed
# OBEROIRLTY.NS
# Out-of-sample profit: [-1344.7027587890625, 29, 18, 18, 0.6206896551724138, 167576.8118671467]
# [*********************100%%**********************]  1 of 1 completed
# HEROMOTOCO.NS
# Out-of-sample profit: [-2158.3984375, 12, 4, 4, 0.3333333333333333, 129056.48686675483]
# [*********************100%%**********************]  1 of 1 completed
# OFSS.NS
# Out-of-sample profit: [2580.437177095452, 12, 6, 6, 0.5, 104432.77660506465]
# [*********************100%%**********************]  1 of 1 completed
# ONGC.NS
# Out-of-sample profit: [-204.60208129882812, 36, 27, 24, 0.75, 141886.9558455074]
# [*********************100%%**********************]  1 of 1 completed
# PEL.NS
# Out-of-sample profit: [-3026.548421630854, 15, 4, 4, 0.26666666666666666, 97950.19334594726]
# [*********************100%%**********************]  1 of 1 completed
# PETRONET.NS
# Out-of-sample profit: [9094.462332680481, 23, 17, 16, 0.7391304347826086, 139403.01770674143]
# [*********************100%%**********************]  1 of 1 completed
# PIDILITIND.NS
# Out-of-sample profit: [6480.30988474441, 10, 6, 6, 0.6, 113022.66727942726]
# [*********************100%%**********************]  1 of 1 completed
# PIIND.NS
# Out-of-sample profit: [4001.152099609375, 26, 19, 19, 0.7307692307692307, 152367.27575019127]
# [*********************100%%**********************]  1 of 1 completed
# IDFCFIRSTB.NS
# Out-of-sample profit: [-109.38998413085938, 26, 20, 20, 0.7692307692307693, 194379.74110143085]
# [*********************100%%**********************]  1 of 1 completed
# PNB.NS
# Out-of-sample profit: [13021.99174666271, 13, 8, 8, 0.6153846153846154, 165891.48100997714]
# [*********************100%%**********************]  1 of 1 completed
# POLYCAB.NS
# Out-of-sample profit: [212.75, 30, 23, 22, 0.7666666666666667, 204740.4188324441]
# [*********************100%%**********************]  1 of 1 completed
# PVRINOX.NS
# Out-of-sample profit: [1010.09619140625, 26, 19, 18, 0.7307692307692307, 142378.97088085974]
# [*********************100%%**********************]  1 of 1 completed
# RAMCOCEM.NS
# Out-of-sample profit: [466.1019287109375, 23, 19, 17, 0.8260869565217391, 161785.17368391377]
# [*********************100%%**********************]  1 of 1 completed
# RBLBANK.NS
# Out-of-sample profit: [716.25, 25, 21, 21, 0.84, 280061.2981368804]
# [*********************100%%**********************]  1 of 1 completed
# RECLTD.NS
# Out-of-sample profit: [11928.0, 10, 8, 8, 0.8, 198166.15720991982]
# [*********************100%%**********************]  1 of 1 completed
# RELIANCE.NS
# Out-of-sample profit: [5290.918617276754, 17, 11, 11, 0.6470588235294118, 120160.45701789191]
# [*********************100%%**********************]  1 of 1 completed
# IPCALAB.NS
# Out-of-sample profit: [4554.532071656282, 15, 10, 9, 0.6666666666666666, 132311.828596704]
# [*********************100%%**********************]  1 of 1 completed
# SAIL.NS
# Out-of-sample profit: [15740.405476764687, 25, 21, 20, 0.84, 183237.85521413438]
# [*********************100%%**********************]  1 of 1 completed
# ITC.NS
# Out-of-sample profit: [7038.990180475814, 24, 21, 21, 0.875, 152003.88672270466]
# [*********************100%%**********************]  1 of 1 completed
# SBICARD.NS
# Out-of-sample profit: [1235.2043571176785, 18, 12, 11, 0.6666666666666666, 125686.85931585725]
# [*********************100%%**********************]  1 of 1 completed
# SBILIFE.NS
# Out-of-sample profit: [151.3065185546875, 21, 15, 15, 0.7142857142857143, 132623.64554531785]
# [*********************100%%**********************]  1 of 1 completed
# SBIN.NS
# Out-of-sample profit: [1091.9952392578125, 6, 3, 3, 0.5, 112869.10541748047]
# [*********************100%%**********************]  1 of 1 completed
# SHREECEM.NS
# Out-of-sample profit: [6625.867289013899, 9, 5, 5, 0.5555555555555556, 123105.21848558442]
# [*********************100%%**********************]  1 of 1 completed
# SRF.NS
# Out-of-sample profit: [-851.6445582151355, 14, 6, 6, 0.42857142857142855, 114933.74776197763]
# [*********************100%%**********************]  1 of 1 completed
# SUNTV.NS
# Out-of-sample profit: [-2520.2977294921875, 18, 9, 9, 0.5, 132757.2410405666]
# [*********************100%%**********************]  1 of 1 completed
# SYNGENE.NS
# Out-of-sample profit: [8574.39945282282, 14, 9, 8, 0.6428571428571429, 120261.64869763539]
# [*********************100%%**********************]  1 of 1 completed
# TATACHEM.NS
# Out-of-sample profit: [3674.556396484375, 20, 14, 14, 0.7, 148107.85236115436]
# [*********************100%%**********************]  1 of 1 completed
# TATACOMM.NS
# Out-of-sample profit: [0, 0, 0, 0, 0, 100000]
# [*********************100%%**********************]  1 of 1 completed
# TATACONSUM.NS
# Out-of-sample profit: [1500.5985107421875, 15, 10, 9, 0.6666666666666666, 116859.97343162373]
# [*********************100%%**********************]  1 of 1 completed
# TATAMOTORS.NS
# Out-of-sample profit: [14559.99755859375, 14, 9, 9, 0.6428571428571429, 143939.5074433589]
# [*********************100%%**********************]  1 of 1 completed
# TATAPOWER.NS
# Out-of-sample profit: [31412.8056640625, 11, 8, 8, 0.7272727272727273, 157138.27397448738]
# [*********************100%%**********************]  1 of 1 completed
# TATASTEEL.NS
# Out-of-sample profit: [-3510.9479219055165, 9, 5, 5, 0.5555555555555556, 113584.60478157045]
# [*********************100%%**********************]  1 of 1 completed
# TCS.NS
# Out-of-sample profit: [9875.370000000006, 8, 4, 4, 0.5, 109309.85789550784]
# [*********************100%%**********************]  1 of 1 completed
# TECHM.NS
# Out-of-sample profit: [98.59716796875, 20, 18, 16, 0.9, 150998.7567373727]
# [*********************100%%**********************]  1 of 1 completed
# TITAN.NS
# Out-of-sample profit: [1259.701904296875, 17, 14, 14, 0.8235294117647058, 146637.9873248428]
# [*********************100%%**********************]  1 of 1 completed
# TORNTPHARM.NS
# Out-of-sample profit: [11288.90465906504, 8, 5, 5, 0.625, 134290.85344187703]
# [*********************100%%**********************]  1 of 1 completed
# TVSMOTOR.NS
# Out-of-sample profit: [1744.465610079793, 25, 20, 19, 0.8, 178975.60177172598]
# [*********************100%%**********************]  1 of 1 completed
# UBL.NS
# Out-of-sample profit: [11118.081492952611, 23, 17, 17, 0.7391304347826086, 129202.64990780917]
# [*********************100%%**********************]  1 of 1 completed
# ULTRACEMCO.NS
# Out-of-sample profit: [645.609375, 13, 10, 10, 0.7692307692307693, 134970.2226195958]
# [*********************100%%**********************]  1 of 1 completed
# UPL.NS
# Out-of-sample profit: [3200.224443969724, 9, 2, 2, 0.2222222222222222, 88438.51880493163]
# [*********************100%%**********************]  1 of 1 completed
# VEDL.NS
# Out-of-sample profit: [3809.5, 11, 5, 5, 0.45454545454545453, 101017.44769808615]
# [*********************100%%**********************]  1 of 1 completed
# WIPRO.NS
# Out-of-sample profit: [-7650.395202636719, 6, 3, 3, 0.5, 102898.89229565427]
# [*********************100%%**********************]  1 of 1 completed
# ZYDUSLIFE.NS
# Out-of-sample profit: [16166.383098144539, 10, 4, 4, 0.4, 138325.7178918457]
# [*********************100%%**********************]  1 of 1 completed
# NAUKRI.NS
# Out-of-sample profit: [5065.1953125, 14, 8, 8, 0.5714285714285714, 122617.23537873116]
# [*********************100%%**********************]  1 of 1 completed
# NAVINFLUOR.NS
# Out-of-sample profit: [1320.0231959925964, 26, 17, 17, 0.6538461538461539, 135312.43222562523]
# [*********************100%%**********************]  1 of 1 completed
# M&MFIN.NS
# Out-of-sample profit: [-3848.0, 28, 18, 17, 0.6428571428571429, 167625.88109478474]
# [*********************100%%**********************]  1 of 1 completed
# MARICO.NS
# Out-of-sample profit: [267.5, 36, 25, 23, 0.6944444444444444, 118996.0572435686]
# [*********************100%%**********************]  1 of 1 completed
# PFC.NS
# Out-of-sample profit: [90923.02187273979, 9, 8, 8, 0.8888888888888888, 242049.35493027925]
# [*********************100%%**********************]  1 of 1 completed
# AARTIIND.NS
# Out-of-sample profit: [5392.608642578125, 15, 12, 12, 0.8, 155246.4200104433]
# [*********************100%%**********************]  1 of 1 completed
# ASIANPAINT.NS
# Out-of-sample profit: [2344.59814453125, 22, 18, 17, 0.8181818181818182, 131059.13249294432]
# [*********************100%%**********************]  1 of 1 completed
# ATUL.NS
# Out-of-sample profit: [1254.589095370391, 16, 11, 11, 0.6875, 123255.13976608458]
# [*********************100%%**********************]  1 of 1 completed
# SUNPHARMA.NS
# Out-of-sample profit: [225.0, 20, 15, 14, 0.75, 125942.20355913915]
# [*********************100%%**********************]  1 of 1 completed
# CUMMINSIND.NS
# Out-of-sample profit: [-1551.0516357421875, 21, 13, 12, 0.6190476190476191, 133996.98017069738]
# [*********************100%%**********************]  1 of 1 completed
# DABUR.NS
# Out-of-sample profit: [395.997314453125, 28, 20, 17, 0.7142857142857143, 121281.8549639391]
# [*********************100%%**********************]  1 of 1 completed
# DEEPAKNTR.NS
# Out-of-sample profit: [6404.452880859375, 31, 20, 19, 0.6451612903225806, 148519.79490585774]
# [*********************100%%**********************]  1 of 1 completed
# EICHERMOT.NS
# Out-of-sample profit: [725.0, 24, 14, 14, 0.5833333333333334, 123923.85825279885]
# [*********************100%%**********************]  1 of 1 completed
# ZEEL.NS
# Out-of-sample profit: [12211.224484972628, 26, 16, 16, 0.6153846153846154, 162818.401504582]
# [*********************100%%**********************]  1 of 1 completed
# ESCORTS.NS
# Out-of-sample profit: [-785.205078125, 20, 16, 16, 0.8, 154591.51480291242]
# [*********************100%%**********************]  1 of 1 completed
# GODREJCP.NS
# Out-of-sample profit: [2134.0, 12, 3, 3, 0.25, 100091.02625251912]
# [*********************100%%**********************]  1 of 1 completed
# GODREJPROP.NS
# Out-of-sample profit: [-6216.145751953125, 17, 13, 13, 0.7647058823529411, 175009.0235692824]
# [*********************100%%**********************]  1 of 1 completed
# HAVELLS.NS
# Out-of-sample profit: [127.39111328125, 16, 12, 11, 0.75, 125415.23718261719]
# [*********************100%%**********************]  1 of 1 completed
# HDFCBANK.NS
# Out-of-sample profit: [-2707.3035864257863, 10, 3, 3, 0.3, 88704.96043823245]
# [*********************100%%**********************]  1 of 1 completed
# INDIGO.NS
# Out-of-sample profit: [13089.30224609375, 12, 7, 7, 0.5833333333333334, 137102.38829844224]
# [*********************100%%**********************]  1 of 1 completed
# INFY.NS
# Out-of-sample profit: [8377.59375, 7, 3, 3, 0.42857142857142855, 98662.24639444325]
# [*********************100%%**********************]  1 of 1 completed
# IOC.NS
# Out-of-sample profit: [-2322.0, 12, 5, 5, 0.4166666666666667, 135233.67697885697]
# [*********************100%%**********************]  1 of 1 completed
# BERGEPAINT.NS
# Out-of-sample profit: [-228.75, 16, 9, 9, 0.5625, 108355.63733310014]
# [*********************100%%**********************]  1 of 1 completed
# LT.NS
# Out-of-sample profit: [15585.895152051326, 9, 5, 5, 0.5555555555555556, 134735.68021426914]
# [*********************100%%**********************]  1 of 1 completed
# MCDOWELL-N.NS
# Out-of-sample profit: [191.8033447265625, 34, 27, 27, 0.7941176470588235, 152931.522368265]
# [*********************100%%**********************]  1 of 1 completed
# IBULHSGFIN.NS
# Out-of-sample profit: [-3260.4030151367188, 22, 16, 15, 0.7272727272727273, 214316.85587827163]
# [*********************100%%**********************]  1 of 1 completed
# M&M.NS
# Out-of-sample profit: [-1857.603515625, 12, 6, 6, 0.5, 123038.00889835913]
# [*********************100%%**********************]  1 of 1 completed
# PAGEIND.NS
# Out-of-sample profit: [4619.25, 29, 22, 22, 0.7586206896551724, 133074.7903778331]
# [*********************100%%**********************]  1 of 1 completed
# SIEMENS.NS
# Out-of-sample profit: [560.0, 21, 16, 15, 0.7619047619047619, 166463.60321237918]
# [*********************100%%**********************]  1 of 1 completed
# COFORGE.NS
# Out-of-sample profit: [1467.354158128277, 17, 15, 14, 0.8823529411764706, 150595.61841754027]
# [*********************100%%**********************]  1 of 1 completed
# HINDUNILVR.NS
# Out-of-sample profit: [4795.8065519085485, 21, 14, 14, 0.6666666666666666, 123926.58353424945]
# [*********************100%%**********************]  1 of 1 completed
# POWERGRID.NS
# Out-of-sample profit: [3822.1598411032974, 11, 6, 6, 0.5454545454545454, 124103.52520854518]
# [*********************100%%**********************]  1 of 1 completed
# VOLTAS.NS
# Out-of-sample profit: [-681.5017700195312, 10, 4, 4, 0.4, 119893.2916724313]

# %%
140/632
# Out:
# 0.22151898734177214
