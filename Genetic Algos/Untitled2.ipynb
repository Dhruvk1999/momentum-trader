# %%
from utility_functions import *
from evolution_operators import *

# %%
cd
# Out:
# /home/dhruv

# %%
cd momentum-trader/
# Out:
# /home/dhruv/momentum-trader

# %%
results.sort_values('Win_rate',ascending = False)[results.Stock == 'COLPAL.NS']
# Out:
# /tmp/ipykernel_50782/1828464596.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   results.sort_values('Win_rate',ascending = False)[results.Stock == 'COLPAL.NS']
#        Stock         Profit  Total_trades  Winning_trades   Win_rate
# 1  COLPAL.NS  149591.358322            22              20  90.909091

# %%
import yfinance as yf
import pandas as pd

results = pd.read_csv('ga_results_inSample') 
parameters_df = pd.read_csv('ga_parameters',index_col = [])

# %%
parameters_df.index = parameters_df['Symbol']

# %%
parameters_df[parameters_df.Symbol == 'GLENMARK.NS']
# Out:
#                                 Best Parameters  Best Fitness Score  \
# Symbol
# GLENMARK.NS  [2, 3, 6, 20, -0.9930604812498026]            1213.075
#
#                   Symbol
# Symbol
# GLENMARK.NS  GLENMARK.NS

# %%
results.sort_values('Win_rate',ascending = False)[results.Stock == 'INDIAMART.NS']
# Out:
# /tmp/ipykernel_50782/2135970073.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   results.sort_values('Win_rate',ascending = False)[results.Stock == 'INDIAMART.NS']
#            Stock         Profit  Total_trades  Winning_trades   Win_rate
# 23  INDIAMART.NS  167827.472077            33              27  81.818182

# %%
results_data[results_data.Entry_Date == '2024-01-11']
# Out:
#           Symbol Entry_Date  Entry_Price            Exit_Date Exit_Price
# 3         SRF.NS 2024-01-11  2325.250000                 None       None
# 1         IEX.NS 2024-01-11   166.899994  2024-01-12 00:00:00      167.5
# 2  CHAMBLFERT.NS 2024-01-11   380.200012                 None       None
# 2        ATUL.NS 2024-01-11  6862.299805                 None       None
# 3        IDFC.NS 2024-01-11   124.800003                 None       None
# 3  INDUSINDBK.NS 2024-01-11  1657.849976                 None       None
# 2  ASIANPAINT.NS 2024-01-11  3288.199951                 None       None

# %%
top_tickers = results.sort_values('Win_rate',ascending = False)[:40]
results_data = pd.DataFrame(columns=['Symbol', 'Entry_Date', 'Entry_Price', 'Exit_Date', 'Exit_Price'])

for ticker in top_tickers.Stock:
    temp_data = pd.DataFrame(columns=['Symbol', 'Entry_Date', 'Entry_Price', 'Exit_Date', 'Exit_Price'])
    parameters = parameters_df.loc[ticker]['Best Parameters'].strip('][').split(', ')
    fast_p = int(parameters[0])
    slow_p = int(parameters[1])
    fast_p_e = int(parameters[2])
    slow_p_e = int(parameters[3])
    sl = float(parameters[-1])
    _,temp_data = evaluate_strategy(ticker,fast_p,slow_p,fast_p_e,slow_p_e,sl,temp_data)
    results_data = pd.concat([results_data,temp_data])
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Entry: 824.0 on 2023-12-15 00:00:00 Stop Loss: 832.1828183654984
# Exit: 825.0 on 2023-12-18 00:00:00 exited on stop loss Allocated Funds 100121.0
# Profit: 121.0
# Entry: 823.5999755859375 on 2023-12-21 00:00:00 Stop Loss: 831.7788214670645
# Exit: 857.0 on 2023-12-29 00:00:00 exited on stop loss Allocated Funds 104162.40295410156
# Profit: 4041.4029541015625
# Entry: 888.7999877929688 on 2024-01-02 00:00:00 Stop Loss: 897.6263092290937
# Exit: 900.0 on 2024-01-05 00:00:00 exited on stop loss Allocated Funds 105472.80438232422
# Profit: 1310.4014282226562
# Entry: 910.4500122070312 on 2024-01-15 00:00:00 Stop Loss: 919.4913314797933
# [*********************100%%**********************]  1 of 1 completed
# Entry: 2486.89990234375 on 2024-01-15 00:00:00 Stop Loss: 2511.597435368229
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
from datetime import date,timedelta
str(date.today()+timedelta(days = 1))
# Out:
# '2024-01-16'

# %%
def evaluate_strategy(symbol, fast_period, slow_period, fast_p_exit, slow_p_exit, stop_loss_percentage,results_data):
    # Calculate indicators
#     print(fast_period,slow_period,fast_p_exit, slow_p_exit, stop_loss_percentage)

    data = yf.download(symbol, start = '2023-12-01',end=str(date.today()+timedelta(days = 1)))
    data['MACD'], data['Signal'] = calculate_macd(data, fast_period, slow_period)
    data['MACD_E'], data['Signal_E'] = calculate_macd(data, fast_p_exit, slow_p_exit)

    data['ROC'] = calculate_roc(data, 3)
#     data['RSI_Derivative'] = calculate_rsi_derivative(data, rsi_period)
    
    # Apply trailing stop-loss exit condition
#     stop_loss = trailing_stop_loss(data, stop_loss_percentage)
    
    # Simulated trading logic
    position = 0  # 0 for no position, 1 for long position
    profit = 0
    total_trades = 0
    winning_trades = 0
    stricly_winning_trades =0
    allocated_funds = 100000
    no_of_shares =0
    stop_loss_price = 0
    
    for i in range(1, len(data)):
        try:

            if position == 0:
                if data['MACD'][i] > data['Signal'][i] :#and data['ROC'][i] > 1: #and data['RSI_Derivative'][i] > rsi_derivative_threshold:
                
                    position = 1  # Buy (enter long position)
                    entry_price = data['Close'][i]
                    stop_loss_price = entry_price - (entry_price * 0.01 * stop_loss_percentage)
                    print(f"Entry: {entry_price} on {data.index[i]} Stop Loss: {stop_loss_price}")
                    total_trades += 1
                    no_of_shares = allocated_funds//entry_price
                    
                    new_data = pd.DataFrame({
                        'Symbol': [symbol],
                        'Entry_Date': [data.index[i]],
                        'Entry_Price': [entry_price],
                        'Exit_Date': [None],
                        'Exit_Price': [None]
                    })
                    results_data = pd.concat([results_data, new_data], ignore_index=True)
                    
                                        # Append signal to the results_data DataFrame


                    
            elif position == 1 and data['MACD'][i] < data['Signal'][i]:
                
                if data['Close'][i] > entry_price:  # Adjust stop loss only when the price goes up
                    stop_loss_price = max(stop_loss_price, data['Close'][i] - (data['Close'][i] * 0.01 * stop_loss_percentage))
                    
                if data['Low'][i] < stop_loss_price:
                    position = 0  # Sell due to stop loss
                    exit_price = data['Open'][i] if stop_loss_price > data['Open'][i] else stop_loss_price
                    trade_profit = (exit_price - entry_price) * no_of_shares  # Calculate profit/loss
                    profit=trade_profit
                    allocated_funds += profit
                    no_of_shares =0
                    print(f"Exit: {exit_price} on {data.index[i]} exited on stop loss Allocated Funds {allocated_funds}")
                    print(f"Profit: {profit}")
                    
                    mask = (results_data['Symbol'] == symbol) & (results_data['Exit_Date'].isnull())
                    results_data.loc[mask, 'Exit_Date'] = data.index[i]
                    results_data.loc[mask, 'Exit_Price'] = exit_price
           
                    if(exit_price>= entry_price):
                        winning_trades += 1
                    if(exit_price> entry_price):
                        stricly_winning_trades += 1
                elif data['MACD_E'][i] < data['Signal_E'][i]:
                    position = 0  # Sell due to exit condition
                    exit_price = data['Close'][i]
                    trade_profit = (exit_price - entry_price) * no_of_shares  # Calculate profit/loss
                    profit=trade_profit#                     
                    print(f"Exit: {exit_price} on {data.index[i]} exited on stop loss Allocated Funds {allocated_funds}")
                    print(f"Profit: {profit}")

                    allocated_funds += profit
                    
                    
                    mask = (results_data['Symbol'] == symbol) & (results_data['Exit_Date'].isnull())
                    results_data.loc[mask, 'Exit_Date'] = data.index[i]
                    results_data.loc[mask, 'Exit_Price'] = exit_price

                    no_of_shares =0
                    if(exit_price>= entry_price):
                        winning_trades += 1
                    if(exit_price> entry_price):
                        stricly_winning_trades += 1
            
        except Exception as ex:
            print("Something caused the error",ex)
            break
        win_rate = winning_trades/total_trades if total_trades != 0 else 0
    
    return [profit,total_trades,winning_trades,stricly_winning_trades,win_rate,allocated_funds],results_data

# %%
r =results_data[results_data['Entry_Date'] == '2024-01-15']
r
# Out:
#           Symbol Entry_Date  Entry_Price Exit_Date Exit_Price
# 3    GLENMARK.NS 2024-01-15   910.450012      None       None
# 0      COLPAL.NS 2024-01-15  2486.899902      None       None
# 2       TITAN.NS 2024-01-15  3758.850098      None       None
# 2     DRREDDY.NS 2024-01-15  5783.250000      None       None
# 0  COROMANDEL.NS 2024-01-15  1205.500000      None       None
# 4        NTPC.NS 2024-01-15   317.299988      None       None
# 1         PFC.NS 2024-01-15   409.500000      None       None

# %%
results.sort_values('Win_rate',ascending = False)[results.Stock == 'SRF.NS']
# Out:
# /tmp/ipykernel_50782/1023620069.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   results.sort_values('Win_rate',ascending = False)[results.Stock == 'SRF.NS']
#     Stock         Profit  Total_trades  Winning_trades  Win_rate
# 4  SRF.NS  159855.206471            32              28      87.5

# %%
parameters = parameters_df.loc['INDIAMART.NS']['Best Parameters'].strip('][').split(', ')

# %%
parameters
# Out:
# ['4', '2', '8', '10', '-0.8498897417943859']
